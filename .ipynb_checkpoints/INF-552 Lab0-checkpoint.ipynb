# %% [markdown]
# <center><h1>INF-552 Lab 0</h1></center>
# <br>
# <center><font size="4">Introduction to Basic Development Tools</font></center>

# %% [markdown]
# ### Rules

# %% [markdown]
# 1. Please read the instructions and problem prompts **carefully**.
# 2. This lab is to give you some basic APIs of numpy, pandas and scikit-learn. Besides, some topics such as how to make your jupyter notebook be a more efficient developing tools, how to use git and GitHub will also be covered. The lab is to be done individually. You may talk to your fellow classmates about general issues ("Remind me again: Which API should I used for doing group by operation to a data set") but about the specifies of how to do these exercises.
# 3. Along with a similar vein, you can ask the TA for help, but ask questions about **concepts** but not ask the TA to help you debug your code. The TA is here to help, but not to do the work for you.
# 4. You are welcome to use the class resources and the Internet.
# 5. Playing with variations. Solve one problems, and then copy the code to a new cell and play around with it. Doing this is the single most important thing when learning programming.
# 6. This lab will not be graded but the content is highly related to your future programming assignments. So, treat it wisely.
# 7. All the content having been gone though in the week 1 discussion is just a snapshot of the most basic concepts. **You need to keep study more about Git, GitHub, Pandas, Numpy and Scikit-Learn in order to finish your programming assignments successfully.**
# 8. Have fun!

# %% [markdown]
# ### Setup Development Environment

# %% [markdown]
# There are many ways to setup the environment. But, I do recommend a simple idea that is using the Anaconda, which is a pre-build python environment with bundles of useful packages.
#
# **To download the Anaconda, go to the following website:
# https://www.anaconda.com/distribution/**. Download the correct version based on your operating system and install it step by step.
#
# Then, **configure your PATH environment variable** to make the conda command work. The following command is an easy way to test whether your configuration is correct. If it is, you will see something as like as the sample output.
#
# > **command:**
# >
# > conda --version
# >
# > **sample output:**
# >
# > conda 4.6.12
#
# **Finally, download this jupyter notebook file,** then change the working directory to where its location in terminal, and type the following command to open the jupter notebook and finish the lab.
#
# > **command:**
# > jupyter notebook

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Pandas

# %% [markdown]
# #### The read_csv() Method

# %% [markdown]
# First, read the documentation about the *read_csv()* method in Pandas (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html). Then, try to read data from file Salaries.csv to a dataframe, make the column playerID in the csv file as the index column and the first row as the header. Also, skip the second row when reading the file.

# %%
salary = pd.read_csv(r'Salaries.csv',skiprows = [2]) 
id_index = salary.set_index('playerID')
salary.head(10)
# Out:
#    yearID teamID lgID   playerID   salary
# 0    1985    ATL   NL  barkele01   870000
# 1    1985    ATL   NL  benedbr01   545000
# 2    1985    ATL   NL   campri01   633333
# 3    1985    ATL   NL  ceronri01   625000
# 4    1985    ATL   NL  chambch01   800000
# 5    1985    ATL   NL  dedmoje01   150000
# 6    1985    ATL   NL  forstte01   483333
# 7    1985    ATL   NL  garbege01   772000
# 8    1985    ATL   NL  harpete01   250000
# 9    1985    ATL   NL  hornebo01  1500000

# %%
new_header = id_index.iloc[0] #grab the first row
id_index = id_index[1:] #take the data less the header row
id_index.columns = new_header #set the header row as the df header

id_index.head(11)
# Out:
# barkele01  1985  ATL  NL   870000
# playerID
# benedbr01  1985  ATL  NL   545000
# campri01   1985  ATL  NL   633333
# ceronri01  1985  ATL  NL   625000
# chambch01  1985  ATL  NL   800000
# dedmoje01  1985  ATL  NL   150000
# forstte01  1985  ATL  NL   483333
# garbege01  1985  ATL  NL   772000
# harpete01  1985  ATL  NL   250000
# hornebo01  1985  ATL  NL  1500000
# hubbagl01  1985  ATL  NL   455000
# mahleri01  1985  ATL  NL   407500

# %% [markdown]
# #### Indexing and Selecting Data

# %% [markdown]
# Select the id of the players who are registered in ATL and HOU and whose salary is higher than one million.

# %%
salary[(salary['salary'] >1000000) & ((salary['teamID'] == 'ATL') | (salary['teamID'] == 'HOU'))]
# Out:
#        yearID teamID lgID   playerID   salary
# 9        1985    ATL   NL  hornebo01  1500000
# 14       1985    ATL   NL  murphda05  1625000
# 19       1985    ATL   NL  suttebr01  1354167
# 215      1985    HOU   NL   ryanno01  1350000
# 558      1986    ATL   NL  hornebo01  1800000
# ...       ...    ...  ...        ...      ...
# 25052    2015    HOU   AL  quallch01  3000000
# 25053    2015    HOU   AL  rasmuco01  8000000
# 25054    2015    HOU   AL  singljo02  2000000
# 25055    2015    HOU   AL   sippto01  2400000
# 25058    2015    HOU   AL  valbulu01  4200000
#
# [595 rows x 5 columns]

# %% [markdown]
# #### The describe() Method

# %% [markdown]
# Calculate the standard Deviation, first quartile, medium, third quartile, mean, maximum, minimum of the salary in team ATL.

# %%
salary[salary['teamID'] == 'ATL'].describe()
# Out:
#             yearID        salary
# count   885.000000  8.850000e+02
# mean   1999.725424  2.208111e+06
# std       8.766470  3.434162e+06
# min    1985.000000  6.000000e+04
# 25%    1992.000000  3.000000e+05
# 50%    1999.000000  6.000000e+05
# 75%    2007.000000  2.400000e+06
# max    2015.000000  1.606180e+07

# %% [markdown]
# #### The iterrows() Method

# %% [markdown]
# Create a Python dictionary object whose keys are the headers of the dataframe created in the read_csv() exercise and values are Python list objects that contain data corresponding to the headers. (Here, use the iterrows method to iterate each row of the dataframe and copy it to a dictionary. However, there is a easier way. Learn how the to_dict() method works by yourself later)

# %%
df = pd.read_csv(r'Salaries.csv') 

headers = df.columns.values.tolist()
d= {}
for head in headers:
    d[head] = list()

for index, row in df.iterrows():
    for head in headers:
        d[head].append(row[head])
d
# Out:
# {'yearID': [1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1985,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   1986,
#   ...],
#  'teamID': ['ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'NYN',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'OAK',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PHI',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'PIT',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SDN',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SFN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'SLN',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TEX',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'TOR',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BAL',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CAL',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHA',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CHN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CIN',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'CLE',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'DET',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'HOU',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'KCA',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'LAN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'MIN',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'ML4',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'MON',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   'NYA',
#   ...],
#  'lgID': ['NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   'AL',
#   ...],
#  'playerID': ['barkele01',
#   'bedrost01',
#   'benedbr01',
#   'campri01',
#   'ceronri01',
#   'chambch01',
#   'dedmoje01',
#   'forstte01',
#   'garbege01',
#   'harpete01',
#   'hornebo01',
#   'hubbagl01',
#   'mahleri01',
#   'mcmurcr01',
#   'mumphje01',
#   'murphda05',
#   'oberkke01',
#   'perezpa01',
#   'perryge01',
#   'ramirra01',
#   'suttebr01',
#   'washicl01',
#   'boddimi01',
#   'dauerri01',
#   'davisst02',
#   'dempsri01',
#   'dwyerji01',
#   'flanami01',
#   'fordda01',
#   'grosswa01',
#   'lacyle01',
#   'lynnfr01',
#   'martide01',
#   'martiti01',
#   'mcgresc01',
#   'murraed02',
#   'nolanjo01',
#   'rayfofl01',
#   'ripkeca01',
#   'roeniga01',
#   'sheetla01',
#   'shelbjo01',
#   'stewasa01',
#   'youngmi01',
#   'armasto01',
#   'barrema02',
#   'boggswa01',
#   'bordiri01',
#   'boydoi01',
#   'bucknbi01',
#   'clearma01',
#   'clemero02',
#   'crawfst01',
#   'easlemi01',
#   'evansdw01',
#   'gedmari01',
#   'gutieja01',
#   'hoffmgl01',
#   'hurstbr01',
#   'juraked01',
#   'kisonbr01',
#   'milleri01',
#   'nichore01',
#   'nippeal01',
#   'ojedabo01',
#   'remyje01',
#   'riceji01',
#   'stanlbo01',
#   'staplda01',
#   'beniqju01',
#   'boonebo01',
#   'burleri01',
#   'candejo01',
#   'carewro01',
#   'clibust02',
#   'corbedo01',
#   'decindo01',
#   'downibr01',
#   'forscke01',
#   'grichbo01',
#   'hendrge01',
#   'hollaal01',
#   'jacksre01',
#   'jonesru01',
#   'lacorfr01',
#   'mccaski01',
#   'mooredo01',
#   'pettiga01',
#   'romanro01',
#   'sanchlu01',
#   'schofdi02',
#   'sconida01',
#   'slatoji01',
#   'suttodo01',
#   'wilforo01',
#   'wittmi01',
#   'zahnge01',
#   'agostju01',
#   'baineha01',
#   'bannifl01',
#   'burnsbr01',
#   'cruzju01',
#   'dotsori01',
#   'fiskca01',
#   'fletcsc01',
#   'guilloz01',
#   'hairsje01',
#   'hillma01',
#   'jamesbo01',
#   'kittlro01',
#   'lawru01',
#   'lollati01',
#   'nelsoge01',
#   'pacioto01',
#   'salazlu01',
#   'seaveto01',
#   'spillda01',
#   'walkegr01',
#   'bosleth01',
#   'brusswa01',
#   'ceyro01',
#   'davisjo02',
#   'dernibo01',
#   'durhale01',
#   'eckerde01',
#   'fontera01',
#   'frazige01',
#   'hebneri01',
#   'lopesda01',
#   'matthga01',
#   'morelke01',
#   'ruthvdi01',
#   'sandbry01',
#   'sandesc01',
#   'smithle02',
#   'sorenla01',
#   'speiech01',
#   'sutclri01',
#   'troutst01',
#   'woodsga01',
#   'bellbu01',
#   'brownto05',
#   'conceda01',
#   'foleyto02',
#   'francjo01',
#   'humeto01',
#   'krencwa01',
#   'mcgafan01',
#   'milneed01',
#   'oestero01',
#   'parkeda01',
#   'pastofr01',
#   'perezto01',
#   'powerte01',
#   'pricejo02',
#   'redusga01',
#   'rosepe01',
#   'sotoma01',
#   'stupejo01',
#   'tibbsja01',
#   'vangoda01',
#   'venabma01',
#   'ayalabe01',
#   'bandoch01',
#   'bernato01',
#   'blylebe01',
#   'butlebr01',
#   'camacer01',
#   'cartejo01',
#   'easteja01',
#   'fischmi01',
#   'francju01',
#   'garlawa01',
#   'hallme01',
#   'hargrmi01',
#   'heatone01',
#   'jacobbr01',
#   'ruhleve01',
#   'tablepa01',
#   'thornan01',
#   'vukovge01',
#   'waddeto01',
#   'berenju01',
#   'bergmda01',
#   'brookto01',
#   'castima02',
#   'evansda01',
#   'gibsoki01',
#   'grubbjo01',
#   'hernawi01',
#   'herndla01',
#   'lapoida01',
#   'lemonch01',
#   'lopezau01',
#   'morrija02',
#   'parrila02',
#   'petryda01',
#   'scherbi01',
#   'terrewa01',
#   'trammal01',
#   'whitalo01',
#   'wilcomi01',
#   'ashbyal01',
#   'basske01',
#   'cabelen01',
#   'cruzjo01',
#   'davisgl01',
#   'dawlebi01',
#   'dipinfr01',
#   'doranbi02',
#   'garneph01',
#   'kneppbo01',
#   'morenom01',
#   'niekrjo01',
#   'puhlte01',
#   'reynocr01',
#   'ryanno01',
#   'scottmi03',
#   'smithda02',
#   'spilmha01',
#   'thondi01',
#   'wallide01',
#   'balbost01',
#   'beckwjo01',
#   'blackbu02',
#   'brettge01',
#   'conceon01',
#   'gubicma01',
#   'jacksda02',
#   'jonesly01',
#   'jonesmi02',
#   'lampde01',
#   'leibrch01',
#   'leonade01',
#   'mcraeha01',
#   'motleda01',
#   'ortajo01',
#   'pryorgr01',
#   'quiseda01',
#   'saberbr01',
#   'sheripa01',
#   'sundbji01',
#   'wathajo01',
#   'wilsowi02',
#   'bailobo01',
#   'brockgr01',
#   'diazca01',
#   'duncama01',
#   'goltzda01',
#   'guerrpe01',
#   'hershor01',
#   'honeyri01',
#   'johnsja01',
#   'landrke01',
#   'maldoca01',
#   'marshmi02',
#   'niedeto01',
#   'oliveal01',
#   'penaal01',
#   'reussje01',
#   'russebi01',
#   'saxst01',
#   'sciosmi01',
#   'valenfe01',
#   'welchbo01',
#   'whitfte01',
#   'yeagest01',
#   'anderal02',
#   'brunato01',
#   'bushra01',
#   'butchjo01',
#   'castijo01',
#   'davisro02',
#   'engleda01',
#   'filsope01',
#   'gaettga01',
#   'hatchmi01',
#   'hrbekke01',
#   'laudnti01',
#   'puckeki01',
#   'salasma01',
#   'schroke01',
#   'smallro02',
#   'smithmi03',
#   'teufeti01',
#   'violafr01',
#   'burrira01',
#   'coopece01',
#   'darwida01',
#   'fingero01',
#   'gantnji01',
#   'haasmo01',
#   'higuete01',
#   'housepa02',
#   'manniri01',
#   'mcclubo01',
#   'molitpa01',
#   'moorech02',
#   'oglivbe01',
#   'romered01',
#   'schrobi01',
#   'simmote01',
#   'vuckope01',
#   'waitsri01',
#   'yountro01',
#   'brookhu01',
#   'dawsoan01',
#   'dilonmi01',
#   'fishebr01',
#   'flynndo01',
#   'francte01',
#   'gullibi01',
#   'lawva01',
#   'leach01',
#   'lucasga01',
#   'nicosst01',
#   'palmeda01',
#   'raineti01',
#   'reardje01',
#   'roberbe01',
#   'schatda01',
#   'smithbr01',
#   'wallati01',
#   'washiul01',
#   'wohlfji01',
#   'baylodo01',
#   'berrada01',
#   'bystrma01',
#   'cowlejo01',
#   'griffke01',
#   'guidrro01',
#   'hassero01',
#   'henderi01',
#   'kempst01',
#   'mattido01',
#   'meachbo01',
#   'montejo01',
#   'niekrph01',
#   'randowi01',
#   'righeda01',
#   'samplbi01',
#   'shirlbo01',
#   'whitsed01',
#   'winfida01',
#   'wynegbu01',
#   'backmwa01',
#   'berenbr01',
#   'bowala01',
#   'cartega01',
#   'darliro01',
#   'fostege01',
#   'gardero01',
#   'goodedw01',
#   'gormato03',
#   'heepda01',
#   'hernake01',
#   'johnsho01',
#   'knighra01',
#   'lynched01',
#   'mcdowro01',
#   'oroscje01',
#   'santara01',
#   'siskdo01',
#   'staubru01',
#   'strawda01',
#   'wilsomo01',
#   'atherke01',
#   'bakerdu01',
#   'birtsti01',
#   'bochtbr01',
#   'codirch01',
#   'collida02',
#   'davismi02',
#   'griffal01',
#   'heathmi02',
#   'hendest01',
#   'howelja01',
#   'johnto01',
#   'kingmda01',
#   'langfri01',
#   'lansfca01',
#   'mccatst01',
#   'murphdw01',
#   'norrimi01',
#   'phillto02',
#   'picciro01',
#   'tellmto01',
#   'aguaylu01',
#   'anderla02',
#   'carltst01',
#   'corcoti01',
#   'dennyjo01',
#   'diazbo01',
#   'grossgr01',
#   'grosske01',
#   'hayesvo01',
#   'hudsoch02',
#   'kniceal01',
#   'koosmje01',
#   'lefebjo01',
#   'maddoga01',
#   'rawlesh01',
#   'ruckeda01',
#   'samueju01',
#   'schmimi01',
#   'virgioz02',
#   'almonbi01',
#   'deleojo01',
#   'guantce01',
#   'hasslan01',
#   'lezcasi01',
#   'madlobi01',
#   'mazzile01',
#   'mcwilla01',
#   'morriji01',
#   'orsuljo01',
#   'penato01',
#   'rayjo01',
#   'reuscri01',
#   'rhoderi01',
#   'robindo01',
#   'scurrro01',
#   'tekulke01',
#   'thompja01',
#   'tunnele01',
#   'bevacku01',
#   'brownbo04',
#   'bumbral01',
#   'draveda01',
#   'flannti01',
#   'garvest01',
#   'gossari01',
#   'gwynnto01',
#   'hawkian01',
#   'hoytla01',
#   'jacksro03',
#   'kennete02',
#   'leffecr01',
#   'martica01',
#   'mcreyke01',
#   'nettlgr01',
#   'roystje01',
#   'shower01',
#   'stoddti01',
#   'templga01',
#   'thurmma01',
#   'wiggial01',
#   'beattji01',
#   'bonneba01',
#   'bradlph01',
#   'cowenal01',
#   'davisal01',
#   'hendeda01',
#   'kearnbo01',
#   'langsma01',
#   'mooremi01',
#   'nunezed01',
#   'owensp01',
#   'percoja01',
#   'phelpke01',
#   'preslji01',
#   'thomago01',
#   'vandeed01',
#   'youngma01',
#   'ziskri01',
#   'bluevi01',
#   'brenlbo01',
#   'brownch02',
#   'davisch01',
#   'davisma01',
#   'driesda01',
#   'garresc01',
#   'gladdda01',
#   'gottji01',
#   'greenda03',
#   'hammaat01',
#   'krukomi01',
#   'laskebi01',
#   'lemasjo01',
#   'leonaje01',
#   'mintogr01',
#   'thompsc01',
#   'trevial01',
#   'trillma01',
#   'youngjo02',
#   'allenne01',
#   'andujjo01',
#   'braunst01',
#   'campbbi02',
#   'cedence01',
#   'clarkja01',
#   'colemvi01',
#   'coxda01',
#   'dayleke01',
#   'dejesiv01',
#   'forscbo01',
#   'harpebr01',
#   'herrto01',
#   'hortori01',
#   'jorgemi01',
#   'kepshku01',
#   'lahtije01',
#   'landrti01',
#   'mcgeewi01',
#   'pendlte01',
#   'porteda02',
#   'smithlo01',
#   'smithoz01',
#   'tudorjo01',
#   'vanslan01',
#   'bannial01',
#   'harrato01',
#   'hootobu01',
#   'houghch01',
#   'johnscl01',
#   'jonesbo02',
#   'mcdowod01',
#   'nolesdi01',
#   'obriepe03',
#   'parrila01',
#   'rozemda01',
#   'schmida01',
#   'slaugdo01',
#   'steinbi02',
#   'stewada01',
#   'tananfr01',
#   'tollewa01',
#   'walkedu01',
#   'wardga01',
#   'wrighge03',
#   'ackerji01',
#   'alexado01',
#   'barfije01',
#   'bellge02',
#   'burroje01',
#   'caudibi01',
#   'clancji01',
#   'fernato01',
#   'garcida01',
#   'henketo01',
#   'iorgga01',
#   'keyji01',
#   'lavelga01',
#   'martibu01',
#   'matusle01',
#   'mosebll01',
#   'mullira01',
#   'stiebda01',
#   'upshawi01',
#   'whitter01',
#   'ackerji01',
#   'assenpa01',
#   'barkele01',
#   'benedbr01',
#   'campri01',
#   'chambch01',
#   'dedmoje01',
#   'garbege01',
#   'harpete01',
#   'hornebo01',
#   'hubbagl01',
#   'johnsjo05',
#   'mahleri01',
#   'mcmurcr01',
#   'morenom01',
#   'motleda01',
#   'murphda05',
#   'oberkke01',
#   'olwined01',
#   'palmeda01',
#   'ramirra01',
#   'samplbi01',
#   'simmote01',
#   'smithza01',
#   'speckcl01',
#   'suttebr01',
#   'thomaan01',
#   'virgioz02',
#   'washicl01',
#   'aasedo01',
#   'beniqju01',
#   'boddimi01',
#   'bonilju01',
#   'bordiri01',
#   'davisst02',
#   'dempsri01',
#   'dixonke01',
#   'dwyerji01',
#   'flanami01',
#   'fordda01',
#   'grosswa01',
#   'gutieja01',
#   'havenbr01',
#   'jonesod01',
#   'lacyle01',
#   'lynnfr01',
#   'martide01',
#   'martiti01',
#   'mcgresc01',
#   'murraed02',
#   'nichore01',
#   'rayfofl01',
#   'ripkeca01',
#   'sheetla01',
#   'shelbjo01',
#   'stefejo01',
#   'trabeji01',
#   'youngmi01',
#   'armasto01',
#   'barrema02',
#   'baylodo01',
#   'boggswa01',
#   'boydoi01',
#   'brownmi01',
#   'bucknbi01',
#   'clemero02',
#   'crawfst01',
#   'evansdw01',
#   'gardnwe01',
#   'gedmari01',
#   'greenmi01',
#   'hendeda01',
#   'hoffmgl01',
#   'hurstbr01',
#   'lollati01',
#   'nippeal01',
#   'owensp01',
#   'quinore01',
#   'riceji01',
#   'romered01',
#   'sambijo01',
#   'schirca01',
#   'stanlbo01',
#   'staplda01',
#   'stewasa01',
#   'sullima02',
#   'trujimi01',
#   'boonebo01',
#   'burleri01',
#   'candejo01',
#   'corbedo01',
#   'decindo01',
#   'downibr01',
#   'finlech01',
#   'forscke01',
#   'forstte01',
#   'grichbo01',
#   'hendrge01',
#   'howelja02',
#   'jacksre01',
#   'johnto01',
#   'jonesru01',
#   'joynewa01',
#   'lucasga01',
#   'mccaski01',
#   'mooredo01',
#   'narroje01',
#   'pettiga01',
#   'romanro01',
#   'ruhleve01',
#   'schofdi02',
#   'slatoji01',
#   'suttodo01',
#   'whitede03',
#   'wilforo01',
#   'wittmi01',
#   'allenne01',
#   'baineha01',
#   'bannifl01',
#   'bonilbo01',
#   'bostoda01',
#   'bradlsc01',
#   'cangejo01',
#   'carltst01',
#   'cowlejo01',
#   'cruzju01',
#   'dotsori01',
#   'fiskca01',
#   'fostege01',
#   'gilesbr01',
#   'guilloz01',
#   'hairsje01',
#   'hillma01',
#   'huletti01',
#   'jamesbo01',
#   'karkoro01',
#   'kittlro01',
#   'mckeojo01',
#   'mormaru01',
#   'nelsoge01',
#   'percoja01',
#   'schmida01',
#   'seaveto01',
#   'skinnjo01',
#   'squirmi01',
#   'thigpbo01',
#   'walkegr01',
#   'bosleth01',
#   'brusswa01',
#   'ceyro01',
#   'davisjo02',
#   'dernibo01',
#   'dunstsh01',
#   'durhale01',
#   'eckerde01',
#   'fontera01',
#   'francte01',
#   'frazige01',
#   'gumpeda01',
#   'hebneri01',
#   'keougma02',
#   'lakest01',
#   'lopesda01',
#   'martimi01',
#   'matthga01',
#   'morelke01',
#   'moyerja01',
#   'mumphje01',
#   'ruthvdi01',
#   'salazlu01',
#   'sandbry01',
#   'sandesc01',
#   'smithle02',
#   'speiech01',
#   'sutclri01',
#   'trillma01',
#   'troutst01',
#   'woodsga01',
#   'bellbu01',
#   'brownto05',
#   'butersa01',
#   'conceda01',
#   'danieka01',
#   'daviser01',
#   'dennyjo01',
#   'diazbo01',
#   'esaskni01',
#   'francjo01',
#   'gullibi01',
#   'jonestr01',
#   'landrbi01',
#   'larkiba01',
#   'milneed01',
#   'murphro01',
#   'oestero01',
#   'parkeda01',
#   'pastofr01',
#   'perezto01',
#   'powerte01',
#   'pricejo02',
#   'robinro01',
#   'rosepe01',
#   'sotoma01',
#   'stillku01',
#   'vangoda01',
#   'venabma01',
#   'welshch01',
#   'willica01',
#   'allanan01',
#   'bailesc01',
#   'bandoch01',
#   'bernato01',
#   'butlebr01',
#   'camacer01',
#   'candito01',
#   'cartejo01',
#   'castica01',
#   'easteja01',
#   'francju01',
#   'garlawa01',
#   'hallme01',
#   'heatone01',
#   'jacobbr01',
#   'kernji01',
#   'mullifr01',
#   'niekrph01',
#   'nixonot01',
#   'nolesdi01',
#   'oelkebr01',
#   'romanjo02',
#   'schroke01',
#   'schuldo01',
#   'snydeco02',
#   'swindgr01',
#   'tablepa01',
#   'thornan01',
#   'waddeto01',
#   'willsfr01',
#   'yettri01',
#   'bergmda01',
#   'brookto01',
#   'campbbi02',
#   'colesda01',
#   'collida02',
#   'evansda01',
#   'gibsoki01',
#   'grubbjo01',
#   'hernawi01',
#   'herndla01',
#   'kinger01',
#   'lagami01',
#   'lapoida01',
#   'lemonch01',
#   'lowrydw01',
#   'morrija02',
#   'onealra01',
#   'parrila02',
#   'petryda01',
#   'sheripa01',
#   'slatoji01',
#   'spilmha01',
#   'tananfr01',
#   'terrewa01',
#   'tollewa01',
#   'trammal01',
#   'whitalo01',
#   'anderla02',
#   'ashbyal01',
#   'basske01',
#   'calhoje01',
#   'cruzjo01',
#   'davisgl01',
#   'dawlebi01',
#   'deshaji01',
#   'dipinfr01',
#   'doranbi02',
#   'garneph01',
#   'hatchbi01',
#   'kerfech01',
#   'kneppbo01',
#   'lopezau01',
#   'mizerjo01',
#   'pankoji01',
#   'puhlte01',
#   'reynocr01',
#   'ryanno01',
#   'scottmi03',
#   'smithda02',
#   'thondi01',
#   'wallide01',
#   'balbost01',
#   'bankhsc01',
#   'biancbu01',
#   'blackbu02',
#   'brettge01',
#   'coneda01',
#   'farrst01',
#   'gubicma01',
#   'hargeal01',
#   'huismma01',
#   'jacksda02',
#   'jonesly01',
#   'kingemi01',
#   'lawru01',
#   'leibrch01',
#   'leonade01',
#   'mcraeha01',
#   'ortajo01',
#   'pryorgr01',
#   'quirkja01',
#   'quiseda01',
#   'saberbr01',
#   'salazan01',
#   'smithlo01',
#   'sundbji01',
#   'wathajo01',
#   'whitefr01',
#   'wilsowi02',
#   'anderda02',
#   'bailobo01',
#   'beckwjo01',
#   'brockgr01',
#   'cabelen01',
#   'cedence01',
#   'duncama01',
#   'gonzajo02',
#   'guerrpe01',
#   'hamilje01',
#   'hershor01',
#   'holtobr01',
#   'honeyri01',
#   'howelke01',
#   'landrke01',
#   'madlobi01',
#   'marshmi02',
#   'matusle01',
#   'niedeto01',
#   'penaal01',
#   'powelde01',
#   'reussje01',
#   'russebi01',
#   'saxst01',
#   'sciosmi01',
#   'stubbfr01',
#   'trevial01',
#   'valenfe01',
#   'vandeed01',
#   'vonohda01',
#   'welchbo01',
#   'willire01',
#   'beanebi01',
#   'blylebe01',
#   'brunato01',
#   'bushra01',
#   'butchjo01',
#   'davisro02',
#   'espinal01',
#   'gaettga01',
#   'gagnegr01',
#   'hatchmi01',
#   'hrbekke01',
#   'jacksro03',
#   'laudnti01',
#   'lombast01',
#   'pastofr01',
#   'portuma01',
#   'puckeki01',
#   'reedje02',
#   'salasma01',
#   'smallro02',
#   'smithmi03',
#   'violafr01',
#   'birkbmi01',
#   'bosioch01',
#   'bragggl01',
#   'ceronri01',
#   'clearma01',
#   'cluttbr01',
#   'coopece01',
#   'darwida01',
#   'deerro01',
#   'gantnji01',
#   'haasmo01',
#   'higuete01',
#   'johnsjo04',
#   'learyti01',
#   'manniri01',
#   'mcclubo01',
#   'molitpa01',
#   'moorech02',
#   'nieveju01',
#   'oglivbe01',
#   'plesada01',
#   'rileser01',
#   'schrobi01',
#   'searara01',
#   'sveumda01',
#   'thomago01',
#   'wegmabi01',
#   'yountro01',
#   'bilarda01',
#   'brookhu01',
#   'burketi01',
#   'dawsoan01',
#   'fitzgmi02',
#   'flynndo01',
#   'galaran01',
#   'heskejo01',
#   'huntra01',
#   'johnswa03',
#   'krencwa01',
#   'lawva01',
#   'leach01',
#   'mcgafan01',
#   'newmaal01',
#   'nietoto01',
#   'raineti01',
#   'reardje01',
#   'riverlu01',
#   'roberbe01',
#   'schatda01',
#   'sebrabo01',
#   'smithbr01',
#   'thompja01',
#   'thompsc01',
#   'tibbsja01',
#   'tomlida01',
#   'wallati01',
#   'webstmi01',
#   'winnihe01',
#   'wohlfji01',
#   'youmafl01',
#   'berrada01',
#   'burnsbr01',
#   'drabedo01',
#   'easlemi01',
#   'espinju01',
#   'fischmi01',
#   'fishebr01',
#   'griffke01',
#   'guidrro01',
#   'hassero01',
#   'henderi01',
#   'johnto01',
#   'kempst01',
#   'mattido01',
#   'montejo01',
#   'morenom01',
#   'niekrjo01',
#   'paglimi01',
#   ...],
#  'salary': [870000,
#   550000,
#   545000,
#   633333,
#   625000,
#   800000,
#   150000,
#   483333,
#   772000,
#   250000,
#   1500000,
#   455000,
#   407500,
#   275000,
#   775000,
#   1625000,
#   616667,
#   450000,
#   120000,
#   750000,
#   1354167,
#   800000,
#   625000,
#   480000,
#   437500,
#   512500,
#   375000,
#   641667,
#   450000,
#   483333,
#   725000,
#   1090000,
#   560000,
#   440000,
#   547143,
#   1472819,
#   341667,
#   128500,
#   800000,
#   558333,
#   60000,
#   130000,
#   581250,
#   121000,
#   915000,
#   272500,
#   1000000,
#   115000,
#   177500,
#   747500,
#   580000,
#   140000,
#   160000,
#   650000,
#   800000,
#   477500,
#   130000,
#   335000,
#   300000,
#   125000,
#   370000,
#   275000,
#   260000,
#   165000,
#   240000,
#   483333,
#   779227,
#   1075000,
#   325000,
#   365000,
#   883000,
#   856667,
#   612500,
#   875000,
#   60000,
#   360000,
#   1100000,
#   808333,
#   633333,
#   700000,
#   737000,
#   625000,
#   1058894,
#   390000,
#   346667,
#   60000,
#   407500,
#   125000,
#   146500,
#   340000,
#   120000,
#   130000,
#   437500,
#   750000,
#   266667,
#   683333,
#   550000,
#   147500,
#   675000,
#   811250,
#   727500,
#   1242333,
#   900000,
#   685000,
#   165000,
#   60000,
#   150000,
#   200000,
#   265000,
#   300000,
#   565000,
#   463000,
#   110000,
#   333333,
#   325000,
#   1136262,
#   390000,
#   195000,
#   215000,
#   375000,
#   1450000,
#   550000,
#   406250,
#   800000,
#   750000,
#   200000,
#   483333,
#   310000,
#   490000,
#   600000,
#   865000,
#   766667,
#   505000,
#   500000,
#   670000,
#   320000,
#   225000,
#   1260000,
#   640000,
#   321667,
#   751297,
#   60000,
#   920000,
#   117500,
#   75000,
#   833333,
#   250000,
#   110000,
#   300000,
#   550000,
#   970000,
#   350000,
#   225000,
#   255000,
#   410000,
#   227500,
#   358858,
#   1071429,
#   250000,
#   60000,
#   60000,
#   155000,
#   303333,
#   225000,
#   400000,
#   650000,
#   425000,
#   115000,
#   110000,
#   265000,
#   190000,
#   455000,
#   200000,
#   210000,
#   458333,
#   225000,
#   140000,
#   295000,
#   285000,
#   1100000,
#   375000,
#   125000,
#   240000,
#   262500,
#   250000,
#   76000,
#   1083333,
#   685000,
#   250000,
#   660000,
#   675000,
#   380000,
#   670000,
#   575000,
#   885000,
#   766667,
#   875000,
#   100000,
#   177500,
#   517143,
#   670000,
#   550000,
#   416667,
#   155000,
#   291667,
#   796383,
#   60000,
#   295000,
#   255000,
#   325000,
#   745000,
#   850000,
#   700000,
#   825000,
#   541667,
#   350000,
#   1350000,
#   360000,
#   500000,
#   160000,
#   675000,
#   341667,
#   205000,
#   358000,
#   465000,
#   1000000,
#   250000,
#   115000,
#   95000,
#   202500,
#   100000,
#   535000,
#   225000,
#   871429,
#   800000,
#   155500,
#   450000,
#   316667,
#   975000,
#   150000,
#   175000,
#   608333,
#   425000,
#   843750,
#   330000,
#   150000,
#   120000,
#   60000,
#   500000,
#   1270000,
#   212000,
#   705000,
#   150000,
#   537500,
#   140000,
#   333000,
#   370000,
#   750000,
#   350000,
#   980000,
#   450000,
#   465000,
#   435000,
#   1200000,
#   643750,
#   316667,
#   500000,
#   62500,
#   425000,
#   120000,
#   320000,
#   550000,
#   650000,
#   215000,
#   120000,
#   415000,
#   293750,
#   560000,
#   145000,
#   130000,
#   60000,
#   150000,
#   728571,
#   335000,
#   110000,
#   375000,
#   581250,
#   1176190,
#   565000,
#   1065000,
#   687500,
#   679167,
#   60000,
#   215000,
#   510000,
#   480000,
#   950000,
#   365000,
#   560000,
#   290000,
#   100000,
#   1000000,
#   540000,
#   460000,
#   1000000,
#   550000,
#   1033333,
#   175000,
#   60000,
#   350000,
#   250000,
#   700000,
#   375000,
#   650000,
#   513500,
#   105000,
#   375000,
#   1200000,
#   850000,
#   95000,
#   375000,
#   290000,
#   565000,
#   650000,
#   308333,
#   810000,
#   477500,
#   250000,
#   120000,
#   1075000,
#   900000,
#   425000,
#   1470000,
#   1420000,
#   455000,
#   100000,
#   637500,
#   600000,
#   600000,
#   680000,
#   435000,
#   637500,
#   800000,
#   1795704,
#   550000,
#   200000,
#   325000,
#   525000,
#   2028571,
#   230000,
#   1942857,
#   100000,
#   450000,
#   150000,
#   260000,
#   1100000,
#   115000,
#   560000,
#   330000,
#   60000,
#   650000,
#   125000,
#   275000,
#   300000,
#   516667,
#   591667,
#   107333,
#   575000,
#   60000,
#   350000,
#   141500,
#   700000,
#   305000,
#   610000,
#   425000,
#   150000,
#   262500,
#   600000,
#   1087500,
#   608333,
#   900000,
#   520000,
#   845833,
#   283107,
#   220000,
#   100000,
#   207500,
#   237000,
#   250500,
#   1075000,
#   220000,
#   1109333,
#   620000,
#   350000,
#   140000,
#   500000,
#   192500,
#   60000,
#   600000,
#   310000,
#   820333,
#   700000,
#   220000,
#   240000,
#   2130300,
#   350000,
#   255000,
#   155000,
#   150000,
#   129166,
#   425000,
#   975500,
#   600000,
#   796667,
#   232500,
#   60000,
#   1075000,
#   632000,
#   200000,
#   645000,
#   520000,
#   350000,
#   830000,
#   1066667,
#   130000,
#   140000,
#   150000,
#   160000,
#   240000,
#   175000,
#   975000,
#   1713333,
#   440000,
#   200000,
#   975000,
#   340000,
#   870000,
#   270000,
#   140000,
#   150000,
#   900000,
#   325000,
#   537500,
#   556250,
#   1137000,
#   130000,
#   512500,
#   470000,
#   437500,
#   125000,
#   400000,
#   225000,
#   310000,
#   183000,
#   160000,
#   228000,
#   97000,
#   114400,
#   175000,
#   180000,
#   71600,
#   690000,
#   315000,
#   159000,
#   272500,
#   250000,
#   385000,
#   60000,
#   550000,
#   195000,
#   767500,
#   85000,
#   135000,
#   170000,
#   275000,
#   355000,
#   630000,
#   355000,
#   500000,
#   900000,
#   865000,
#   197000,
#   462500,
#   709714,
#   375000,
#   750000,
#   1030000,
#   160000,
#   457500,
#   562500,
#   1555000,
#   60000,
#   110000,
#   150000,
#   700000,
#   583333,
#   135000,
#   560000,
#   110000,
#   200000,
#   100000,
#   250000,
#   208750,
#   475000,
#   112500,
#   740000,
#   740000,
#   1440000,
#   457500,
#   170000,
#   350000,
#   650000,
#   565000,
#   636667,
#   683333,
#   117500,
#   60000,
#   235000,
#   165000,
#   560000,
#   310000,
#   344000,
#   215000,
#   250000,
#   505000,
#   590000,
#   135000,
#   185000,
#   720000,
#   400000,
#   170000,
#   875000,
#   325000,
#   335000,
#   350000,
#   833333,
#   580000,
#   127500,
#   740000,
#   60000,
#   256667,
#   131250,
#   475000,
#   356300,
#   185000,
#   587500,
#   325000,
#   1000000,
#   730000,
#   370000,
#   367500,
#   60000,
#   880000,
#   565000,
#   600000,
#   769452,
#   200000,
#   786667,
#   425000,
#   1800000,
#   505000,
#   105000,
#   687500,
#   225000,
#   100000,
#   257500,
#   1825000,
#   825000,
#   60000,
#   390000,
#   825000,
#   470000,
#   1000000,
#   200000,
#   60000,
#   1729167,
#   60000,
#   575000,
#   750000,
#   600000,
#   450000,
#   837500,
#   120000,
#   250000,
#   510000,
#   442066,
#   140000,
#   400000,
#   639791,
#   350000,
#   450000,
#   167500,
#   115000,
#   107500,
#   725000,
#   1190000,
#   560458,
#   487078,
#   911051,
#   925814,
#   285000,
#   310000,
#   1150000,
#   120000,
#   240000,
#   70000,
#   60000,
#   387500,
#   1000000,
#   435000,
#   660696,
#   1350000,
#   375000,
#   80000,
#   785000,
#   340000,
#   330000,
#   1017757,
#   70000,
#   650000,
#   60000,
#   412000,
#   350000,
#   495000,
#   541250,
#   265000,
#   255000,
#   60000,
#   1984423,
#   375000,
#   500000,
#   75000,
#   1060000,
#   300000,
#   381113,
#   110000,
#   85000,
#   853479,
#   856667,
#   800000,
#   410000,
#   1200000,
#   808333,
#   60000,
#   100000,
#   170000,
#   500000,
#   939333,
#   82500,
#   1102946,
#   440000,
#   560000,
#   65000,
#   500000,
#   142000,
#   1000000,
#   142000,
#   300000,
#   425000,
#   60000,
#   210000,
#   400000,
#   890000,
#   60000,
#   416667,
#   933333,
#   900000,
#   775000,
#   930000,
#   115000,
#   68000,
#   66500,
#   60000,
#   60000,
#   295000,
#   600000,
#   975000,
#   875000,
#   60000,
#   80000,
#   150000,
#   156667,
#   200000,
#   195000,
#   555000,
#   60000,
#   400000,
#   60000,
#   60000,
#   240000,
#   150000,
#   465000,
#   1132652,
#   75000,
#   200000,
#   60000,
#   400000,
#   327500,
#   575000,
#   1400000,
#   833333,
#   558333,
#   100000,
#   983333,
#   783333,
#   240000,
#   250000,
#   633333,
#   64000,
#   100000,
#   100000,
#   60000,
#   490000,
#   60000,
#   850000,
#   760000,
#   60000,
#   850000,
#   1050000,
#   325000,
#   665000,
#   800000,
#   720000,
#   275000,
#   1530000,
#   550000,
#   890000,
#   325000,
#   870000,
#   215000,
#   102500,
#   920000,
#   60000,
#   90000,
#   1083333,
#   775000,
#   272500,
#   195000,
#   545555,
#   60000,
#   60000,
#   60000,
#   350000,
#   60000,
#   650000,
#   1100000,
#   405000,
#   275000,
#   500000,
#   430000,
#   92500,
#   1000000,
#   1150000,
#   60000,
#   150000,
#   225000,
#   80000,
#   70000,
#   60000,
#   60000,
#   225000,
#   580000,
#   850000,
#   145000,
#   80000,
#   190000,
#   177500,
#   350000,
#   575000,
#   215000,
#   350000,
#   310000,
#   437500,
#   90000,
#   60000,
#   300000,
#   97500,
#   110000,
#   65000,
#   60000,
#   275000,
#   110000,
#   60000,
#   60000,
#   395000,
#   1100000,
#   270000,
#   92000,
#   60000,
#   316667,
#   325000,
#   200000,
#   75000,
#   700000,
#   793333,
#   1200000,
#   250000,
#   960000,
#   687500,
#   60000,
#   72500,
#   550000,
#   698571,
#   62500,
#   875000,
#   80000,
#   850000,
#   875000,
#   150000,
#   60000,
#   60000,
#   662500,
#   260000,
#   275000,
#   567143,
#   670000,
#   60000,
#   525000,
#   310000,
#   95000,
#   755000,
#   120000,
#   325000,
#   65000,
#   280000,
#   550000,
#   600000,
#   80000,
#   65000,
#   1000000,
#   223275,
#   60000,
#   85000,
#   850000,
#   416667,
#   1125000,
#   666667,
#   650000,
#   600000,
#   366667,
#   525000,
#   60000,
#   165000,
#   645000,
#   1471429,
#   60000,
#   85000,
#   250000,
#   67000,
#   100000,
#   175000,
#   185000,
#   60000,
#   360000,
#   770000,
#   883333,
#   650000,
#   450000,
#   293808,
#   150000,
#   925000,
#   925000,
#   75000,
#   1000000,
#   653128,
#   400000,
#   485000,
#   1175000,
#   200000,
#   375000,
#   200000,
#   325000,
#   450000,
#   200000,
#   150000,
#   65000,
#   1370000,
#   60000,
#   1000000,
#   60000,
#   755000,
#   175000,
#   637500,
#   841667,
#   650000,
#   220000,
#   531250,
#   350000,
#   62000,
#   1000000,
#   450000,
#   584624,
#   800000,
#   65000,
#   409485,
#   1600000,
#   455000,
#   68500,
#   743750,
#   60000,
#   65000,
#   1450000,
#   740000,
#   220000,
#   385000,
#   725000,
#   60000,
#   515000,
#   100000,
#   666667,
#   1060000,
#   115000,
#   155000,
#   75000,
#   60000,
#   62500,
#   255000,
#   60000,
#   115000,
#   740000,
#   450000,
#   674000,
#   60000,
#   60000,
#   60000,
#   675000,
#   671560,
#   60000,
#   607322,
#   610000,
#   95000,
#   887500,
#   779167,
#   195000,
#   60000,
#   90000,
#   495000,
#   487500,
#   1160000,
#   402500,
#   70000,
#   766593,
#   60000,
#   175000,
#   155000,
#   121500,
#   60000,
#   60000,
#   70000,
#   950000,
#   80000,
#   650000,
#   160000,
#   1047000,
#   147000,
#   325000,
#   67500,
#   170000,
#   65000,
#   65000,
#   320000,
#   450000,
#   850000,
#   180000,
#   62500,
#   90000,
#   1515000,
#   850000,
#   60000,
#   138100,
#   415000,
#   61500,
#   700000,
#   1000000,
#   170000,
#   127500,
#   60000,
#   650000,
#   120000,
#   87500,
#   350000,
#   70000,
#   557500,
#   750000,
#   60000,
#   658333,
#   65000,
#   200000,
#   120000,
#   1050000,
#   975000,
#   400873,
#   1570000,
#   60000,
#   1220000,
#   1375000,
#   716667,
#   500000,
#   750000,
#   120000,
#   ...]}

# %%
df.to_dict()
# Out:
# {'yearID': {0: 1985,
#   1: 1985,
#   2: 1985,
#   3: 1985,
#   4: 1985,
#   5: 1985,
#   6: 1985,
#   7: 1985,
#   8: 1985,
#   9: 1985,
#   10: 1985,
#   11: 1985,
#   12: 1985,
#   13: 1985,
#   14: 1985,
#   15: 1985,
#   16: 1985,
#   17: 1985,
#   18: 1985,
#   19: 1985,
#   20: 1985,
#   21: 1985,
#   22: 1985,
#   23: 1985,
#   24: 1985,
#   25: 1985,
#   26: 1985,
#   27: 1985,
#   28: 1985,
#   29: 1985,
#   30: 1985,
#   31: 1985,
#   32: 1985,
#   33: 1985,
#   34: 1985,
#   35: 1985,
#   36: 1985,
#   37: 1985,
#   38: 1985,
#   39: 1985,
#   40: 1985,
#   41: 1985,
#   42: 1985,
#   43: 1985,
#   44: 1985,
#   45: 1985,
#   46: 1985,
#   47: 1985,
#   48: 1985,
#   49: 1985,
#   50: 1985,
#   51: 1985,
#   52: 1985,
#   53: 1985,
#   54: 1985,
#   55: 1985,
#   56: 1985,
#   57: 1985,
#   58: 1985,
#   59: 1985,
#   60: 1985,
#   61: 1985,
#   62: 1985,
#   63: 1985,
#   64: 1985,
#   65: 1985,
#   66: 1985,
#   67: 1985,
#   68: 1985,
#   69: 1985,
#   70: 1985,
#   71: 1985,
#   72: 1985,
#   73: 1985,
#   74: 1985,
#   75: 1985,
#   76: 1985,
#   77: 1985,
#   78: 1985,
#   79: 1985,
#   80: 1985,
#   81: 1985,
#   82: 1985,
#   83: 1985,
#   84: 1985,
#   85: 1985,
#   86: 1985,
#   87: 1985,
#   88: 1985,
#   89: 1985,
#   90: 1985,
#   91: 1985,
#   92: 1985,
#   93: 1985,
#   94: 1985,
#   95: 1985,
#   96: 1985,
#   97: 1985,
#   98: 1985,
#   99: 1985,
#   100: 1985,
#   101: 1985,
#   102: 1985,
#   103: 1985,
#   104: 1985,
#   105: 1985,
#   106: 1985,
#   107: 1985,
#   108: 1985,
#   109: 1985,
#   110: 1985,
#   111: 1985,
#   112: 1985,
#   113: 1985,
#   114: 1985,
#   115: 1985,
#   116: 1985,
#   117: 1985,
#   118: 1985,
#   119: 1985,
#   120: 1985,
#   121: 1985,
#   122: 1985,
#   123: 1985,
#   124: 1985,
#   125: 1985,
#   126: 1985,
#   127: 1985,
#   128: 1985,
#   129: 1985,
#   130: 1985,
#   131: 1985,
#   132: 1985,
#   133: 1985,
#   134: 1985,
#   135: 1985,
#   136: 1985,
#   137: 1985,
#   138: 1985,
#   139: 1985,
#   140: 1985,
#   141: 1985,
#   142: 1985,
#   143: 1985,
#   144: 1985,
#   145: 1985,
#   146: 1985,
#   147: 1985,
#   148: 1985,
#   149: 1985,
#   150: 1985,
#   151: 1985,
#   152: 1985,
#   153: 1985,
#   154: 1985,
#   155: 1985,
#   156: 1985,
#   157: 1985,
#   158: 1985,
#   159: 1985,
#   160: 1985,
#   161: 1985,
#   162: 1985,
#   163: 1985,
#   164: 1985,
#   165: 1985,
#   166: 1985,
#   167: 1985,
#   168: 1985,
#   169: 1985,
#   170: 1985,
#   171: 1985,
#   172: 1985,
#   173: 1985,
#   174: 1985,
#   175: 1985,
#   176: 1985,
#   177: 1985,
#   178: 1985,
#   179: 1985,
#   180: 1985,
#   181: 1985,
#   182: 1985,
#   183: 1985,
#   184: 1985,
#   185: 1985,
#   186: 1985,
#   187: 1985,
#   188: 1985,
#   189: 1985,
#   190: 1985,
#   191: 1985,
#   192: 1985,
#   193: 1985,
#   194: 1985,
#   195: 1985,
#   196: 1985,
#   197: 1985,
#   198: 1985,
#   199: 1985,
#   200: 1985,
#   201: 1985,
#   202: 1985,
#   203: 1985,
#   204: 1985,
#   205: 1985,
#   206: 1985,
#   207: 1985,
#   208: 1985,
#   209: 1985,
#   210: 1985,
#   211: 1985,
#   212: 1985,
#   213: 1985,
#   214: 1985,
#   215: 1985,
#   216: 1985,
#   217: 1985,
#   218: 1985,
#   219: 1985,
#   220: 1985,
#   221: 1985,
#   222: 1985,
#   223: 1985,
#   224: 1985,
#   225: 1985,
#   226: 1985,
#   227: 1985,
#   228: 1985,
#   229: 1985,
#   230: 1985,
#   231: 1985,
#   232: 1985,
#   233: 1985,
#   234: 1985,
#   235: 1985,
#   236: 1985,
#   237: 1985,
#   238: 1985,
#   239: 1985,
#   240: 1985,
#   241: 1985,
#   242: 1985,
#   243: 1985,
#   244: 1985,
#   245: 1985,
#   246: 1985,
#   247: 1985,
#   248: 1985,
#   249: 1985,
#   250: 1985,
#   251: 1985,
#   252: 1985,
#   253: 1985,
#   254: 1985,
#   255: 1985,
#   256: 1985,
#   257: 1985,
#   258: 1985,
#   259: 1985,
#   260: 1985,
#   261: 1985,
#   262: 1985,
#   263: 1985,
#   264: 1985,
#   265: 1985,
#   266: 1985,
#   267: 1985,
#   268: 1985,
#   269: 1985,
#   270: 1985,
#   271: 1985,
#   272: 1985,
#   273: 1985,
#   274: 1985,
#   275: 1985,
#   276: 1985,
#   277: 1985,
#   278: 1985,
#   279: 1985,
#   280: 1985,
#   281: 1985,
#   282: 1985,
#   283: 1985,
#   284: 1985,
#   285: 1985,
#   286: 1985,
#   287: 1985,
#   288: 1985,
#   289: 1985,
#   290: 1985,
#   291: 1985,
#   292: 1985,
#   293: 1985,
#   294: 1985,
#   295: 1985,
#   296: 1985,
#   297: 1985,
#   298: 1985,
#   299: 1985,
#   300: 1985,
#   301: 1985,
#   302: 1985,
#   303: 1985,
#   304: 1985,
#   305: 1985,
#   306: 1985,
#   307: 1985,
#   308: 1985,
#   309: 1985,
#   310: 1985,
#   311: 1985,
#   312: 1985,
#   313: 1985,
#   314: 1985,
#   315: 1985,
#   316: 1985,
#   317: 1985,
#   318: 1985,
#   319: 1985,
#   320: 1985,
#   321: 1985,
#   322: 1985,
#   323: 1985,
#   324: 1985,
#   325: 1985,
#   326: 1985,
#   327: 1985,
#   328: 1985,
#   329: 1985,
#   330: 1985,
#   331: 1985,
#   332: 1985,
#   333: 1985,
#   334: 1985,
#   335: 1985,
#   336: 1985,
#   337: 1985,
#   338: 1985,
#   339: 1985,
#   340: 1985,
#   341: 1985,
#   342: 1985,
#   343: 1985,
#   344: 1985,
#   345: 1985,
#   346: 1985,
#   347: 1985,
#   348: 1985,
#   349: 1985,
#   350: 1985,
#   351: 1985,
#   352: 1985,
#   353: 1985,
#   354: 1985,
#   355: 1985,
#   356: 1985,
#   357: 1985,
#   358: 1985,
#   359: 1985,
#   360: 1985,
#   361: 1985,
#   362: 1985,
#   363: 1985,
#   364: 1985,
#   365: 1985,
#   366: 1985,
#   367: 1985,
#   368: 1985,
#   369: 1985,
#   370: 1985,
#   371: 1985,
#   372: 1985,
#   373: 1985,
#   374: 1985,
#   375: 1985,
#   376: 1985,
#   377: 1985,
#   378: 1985,
#   379: 1985,
#   380: 1985,
#   381: 1985,
#   382: 1985,
#   383: 1985,
#   384: 1985,
#   385: 1985,
#   386: 1985,
#   387: 1985,
#   388: 1985,
#   389: 1985,
#   390: 1985,
#   391: 1985,
#   392: 1985,
#   393: 1985,
#   394: 1985,
#   395: 1985,
#   396: 1985,
#   397: 1985,
#   398: 1985,
#   399: 1985,
#   400: 1985,
#   401: 1985,
#   402: 1985,
#   403: 1985,
#   404: 1985,
#   405: 1985,
#   406: 1985,
#   407: 1985,
#   408: 1985,
#   409: 1985,
#   410: 1985,
#   411: 1985,
#   412: 1985,
#   413: 1985,
#   414: 1985,
#   415: 1985,
#   416: 1985,
#   417: 1985,
#   418: 1985,
#   419: 1985,
#   420: 1985,
#   421: 1985,
#   422: 1985,
#   423: 1985,
#   424: 1985,
#   425: 1985,
#   426: 1985,
#   427: 1985,
#   428: 1985,
#   429: 1985,
#   430: 1985,
#   431: 1985,
#   432: 1985,
#   433: 1985,
#   434: 1985,
#   435: 1985,
#   436: 1985,
#   437: 1985,
#   438: 1985,
#   439: 1985,
#   440: 1985,
#   441: 1985,
#   442: 1985,
#   443: 1985,
#   444: 1985,
#   445: 1985,
#   446: 1985,
#   447: 1985,
#   448: 1985,
#   449: 1985,
#   450: 1985,
#   451: 1985,
#   452: 1985,
#   453: 1985,
#   454: 1985,
#   455: 1985,
#   456: 1985,
#   457: 1985,
#   458: 1985,
#   459: 1985,
#   460: 1985,
#   461: 1985,
#   462: 1985,
#   463: 1985,
#   464: 1985,
#   465: 1985,
#   466: 1985,
#   467: 1985,
#   468: 1985,
#   469: 1985,
#   470: 1985,
#   471: 1985,
#   472: 1985,
#   473: 1985,
#   474: 1985,
#   475: 1985,
#   476: 1985,
#   477: 1985,
#   478: 1985,
#   479: 1985,
#   480: 1985,
#   481: 1985,
#   482: 1985,
#   483: 1985,
#   484: 1985,
#   485: 1985,
#   486: 1985,
#   487: 1985,
#   488: 1985,
#   489: 1985,
#   490: 1985,
#   491: 1985,
#   492: 1985,
#   493: 1985,
#   494: 1985,
#   495: 1985,
#   496: 1985,
#   497: 1985,
#   498: 1985,
#   499: 1985,
#   500: 1985,
#   501: 1985,
#   502: 1985,
#   503: 1985,
#   504: 1985,
#   505: 1985,
#   506: 1985,
#   507: 1985,
#   508: 1985,
#   509: 1985,
#   510: 1985,
#   511: 1985,
#   512: 1985,
#   513: 1985,
#   514: 1985,
#   515: 1985,
#   516: 1985,
#   517: 1985,
#   518: 1985,
#   519: 1985,
#   520: 1985,
#   521: 1985,
#   522: 1985,
#   523: 1985,
#   524: 1985,
#   525: 1985,
#   526: 1985,
#   527: 1985,
#   528: 1985,
#   529: 1985,
#   530: 1985,
#   531: 1985,
#   532: 1985,
#   533: 1985,
#   534: 1985,
#   535: 1985,
#   536: 1985,
#   537: 1985,
#   538: 1985,
#   539: 1985,
#   540: 1985,
#   541: 1985,
#   542: 1985,
#   543: 1985,
#   544: 1985,
#   545: 1985,
#   546: 1985,
#   547: 1985,
#   548: 1985,
#   549: 1985,
#   550: 1986,
#   551: 1986,
#   552: 1986,
#   553: 1986,
#   554: 1986,
#   555: 1986,
#   556: 1986,
#   557: 1986,
#   558: 1986,
#   559: 1986,
#   560: 1986,
#   561: 1986,
#   562: 1986,
#   563: 1986,
#   564: 1986,
#   565: 1986,
#   566: 1986,
#   567: 1986,
#   568: 1986,
#   569: 1986,
#   570: 1986,
#   571: 1986,
#   572: 1986,
#   573: 1986,
#   574: 1986,
#   575: 1986,
#   576: 1986,
#   577: 1986,
#   578: 1986,
#   579: 1986,
#   580: 1986,
#   581: 1986,
#   582: 1986,
#   583: 1986,
#   584: 1986,
#   585: 1986,
#   586: 1986,
#   587: 1986,
#   588: 1986,
#   589: 1986,
#   590: 1986,
#   591: 1986,
#   592: 1986,
#   593: 1986,
#   594: 1986,
#   595: 1986,
#   596: 1986,
#   597: 1986,
#   598: 1986,
#   599: 1986,
#   600: 1986,
#   601: 1986,
#   602: 1986,
#   603: 1986,
#   604: 1986,
#   605: 1986,
#   606: 1986,
#   607: 1986,
#   608: 1986,
#   609: 1986,
#   610: 1986,
#   611: 1986,
#   612: 1986,
#   613: 1986,
#   614: 1986,
#   615: 1986,
#   616: 1986,
#   617: 1986,
#   618: 1986,
#   619: 1986,
#   620: 1986,
#   621: 1986,
#   622: 1986,
#   623: 1986,
#   624: 1986,
#   625: 1986,
#   626: 1986,
#   627: 1986,
#   628: 1986,
#   629: 1986,
#   630: 1986,
#   631: 1986,
#   632: 1986,
#   633: 1986,
#   634: 1986,
#   635: 1986,
#   636: 1986,
#   637: 1986,
#   638: 1986,
#   639: 1986,
#   640: 1986,
#   641: 1986,
#   642: 1986,
#   643: 1986,
#   644: 1986,
#   645: 1986,
#   646: 1986,
#   647: 1986,
#   648: 1986,
#   649: 1986,
#   650: 1986,
#   651: 1986,
#   652: 1986,
#   653: 1986,
#   654: 1986,
#   655: 1986,
#   656: 1986,
#   657: 1986,
#   658: 1986,
#   659: 1986,
#   660: 1986,
#   661: 1986,
#   662: 1986,
#   663: 1986,
#   664: 1986,
#   665: 1986,
#   666: 1986,
#   667: 1986,
#   668: 1986,
#   669: 1986,
#   670: 1986,
#   671: 1986,
#   672: 1986,
#   673: 1986,
#   674: 1986,
#   675: 1986,
#   676: 1986,
#   677: 1986,
#   678: 1986,
#   679: 1986,
#   680: 1986,
#   681: 1986,
#   682: 1986,
#   683: 1986,
#   684: 1986,
#   685: 1986,
#   686: 1986,
#   687: 1986,
#   688: 1986,
#   689: 1986,
#   690: 1986,
#   691: 1986,
#   692: 1986,
#   693: 1986,
#   694: 1986,
#   695: 1986,
#   696: 1986,
#   697: 1986,
#   698: 1986,
#   699: 1986,
#   700: 1986,
#   701: 1986,
#   702: 1986,
#   703: 1986,
#   704: 1986,
#   705: 1986,
#   706: 1986,
#   707: 1986,
#   708: 1986,
#   709: 1986,
#   710: 1986,
#   711: 1986,
#   712: 1986,
#   713: 1986,
#   714: 1986,
#   715: 1986,
#   716: 1986,
#   717: 1986,
#   718: 1986,
#   719: 1986,
#   720: 1986,
#   721: 1986,
#   722: 1986,
#   723: 1986,
#   724: 1986,
#   725: 1986,
#   726: 1986,
#   727: 1986,
#   728: 1986,
#   729: 1986,
#   730: 1986,
#   731: 1986,
#   732: 1986,
#   733: 1986,
#   734: 1986,
#   735: 1986,
#   736: 1986,
#   737: 1986,
#   738: 1986,
#   739: 1986,
#   740: 1986,
#   741: 1986,
#   742: 1986,
#   743: 1986,
#   744: 1986,
#   745: 1986,
#   746: 1986,
#   747: 1986,
#   748: 1986,
#   749: 1986,
#   750: 1986,
#   751: 1986,
#   752: 1986,
#   753: 1986,
#   754: 1986,
#   755: 1986,
#   756: 1986,
#   757: 1986,
#   758: 1986,
#   759: 1986,
#   760: 1986,
#   761: 1986,
#   762: 1986,
#   763: 1986,
#   764: 1986,
#   765: 1986,
#   766: 1986,
#   767: 1986,
#   768: 1986,
#   769: 1986,
#   770: 1986,
#   771: 1986,
#   772: 1986,
#   773: 1986,
#   774: 1986,
#   775: 1986,
#   776: 1986,
#   777: 1986,
#   778: 1986,
#   779: 1986,
#   780: 1986,
#   781: 1986,
#   782: 1986,
#   783: 1986,
#   784: 1986,
#   785: 1986,
#   786: 1986,
#   787: 1986,
#   788: 1986,
#   789: 1986,
#   790: 1986,
#   791: 1986,
#   792: 1986,
#   793: 1986,
#   794: 1986,
#   795: 1986,
#   796: 1986,
#   797: 1986,
#   798: 1986,
#   799: 1986,
#   800: 1986,
#   801: 1986,
#   802: 1986,
#   803: 1986,
#   804: 1986,
#   805: 1986,
#   806: 1986,
#   807: 1986,
#   808: 1986,
#   809: 1986,
#   810: 1986,
#   811: 1986,
#   812: 1986,
#   813: 1986,
#   814: 1986,
#   815: 1986,
#   816: 1986,
#   817: 1986,
#   818: 1986,
#   819: 1986,
#   820: 1986,
#   821: 1986,
#   822: 1986,
#   823: 1986,
#   824: 1986,
#   825: 1986,
#   826: 1986,
#   827: 1986,
#   828: 1986,
#   829: 1986,
#   830: 1986,
#   831: 1986,
#   832: 1986,
#   833: 1986,
#   834: 1986,
#   835: 1986,
#   836: 1986,
#   837: 1986,
#   838: 1986,
#   839: 1986,
#   840: 1986,
#   841: 1986,
#   842: 1986,
#   843: 1986,
#   844: 1986,
#   845: 1986,
#   846: 1986,
#   847: 1986,
#   848: 1986,
#   849: 1986,
#   850: 1986,
#   851: 1986,
#   852: 1986,
#   853: 1986,
#   854: 1986,
#   855: 1986,
#   856: 1986,
#   857: 1986,
#   858: 1986,
#   859: 1986,
#   860: 1986,
#   861: 1986,
#   862: 1986,
#   863: 1986,
#   864: 1986,
#   865: 1986,
#   866: 1986,
#   867: 1986,
#   868: 1986,
#   869: 1986,
#   870: 1986,
#   871: 1986,
#   872: 1986,
#   873: 1986,
#   874: 1986,
#   875: 1986,
#   876: 1986,
#   877: 1986,
#   878: 1986,
#   879: 1986,
#   880: 1986,
#   881: 1986,
#   882: 1986,
#   883: 1986,
#   884: 1986,
#   885: 1986,
#   886: 1986,
#   887: 1986,
#   888: 1986,
#   889: 1986,
#   890: 1986,
#   891: 1986,
#   892: 1986,
#   893: 1986,
#   894: 1986,
#   895: 1986,
#   896: 1986,
#   897: 1986,
#   898: 1986,
#   899: 1986,
#   900: 1986,
#   901: 1986,
#   902: 1986,
#   903: 1986,
#   904: 1986,
#   905: 1986,
#   906: 1986,
#   907: 1986,
#   908: 1986,
#   909: 1986,
#   910: 1986,
#   911: 1986,
#   912: 1986,
#   913: 1986,
#   914: 1986,
#   915: 1986,
#   916: 1986,
#   917: 1986,
#   918: 1986,
#   919: 1986,
#   920: 1986,
#   921: 1986,
#   922: 1986,
#   923: 1986,
#   924: 1986,
#   925: 1986,
#   926: 1986,
#   927: 1986,
#   928: 1986,
#   929: 1986,
#   930: 1986,
#   931: 1986,
#   932: 1986,
#   933: 1986,
#   934: 1986,
#   935: 1986,
#   936: 1986,
#   937: 1986,
#   938: 1986,
#   939: 1986,
#   940: 1986,
#   941: 1986,
#   942: 1986,
#   943: 1986,
#   944: 1986,
#   945: 1986,
#   946: 1986,
#   947: 1986,
#   948: 1986,
#   949: 1986,
#   950: 1986,
#   951: 1986,
#   952: 1986,
#   953: 1986,
#   954: 1986,
#   955: 1986,
#   956: 1986,
#   957: 1986,
#   958: 1986,
#   959: 1986,
#   960: 1986,
#   961: 1986,
#   962: 1986,
#   963: 1986,
#   964: 1986,
#   965: 1986,
#   966: 1986,
#   967: 1986,
#   968: 1986,
#   969: 1986,
#   970: 1986,
#   971: 1986,
#   972: 1986,
#   973: 1986,
#   974: 1986,
#   975: 1986,
#   976: 1986,
#   977: 1986,
#   978: 1986,
#   979: 1986,
#   980: 1986,
#   981: 1986,
#   982: 1986,
#   983: 1986,
#   984: 1986,
#   985: 1986,
#   986: 1986,
#   987: 1986,
#   988: 1986,
#   989: 1986,
#   990: 1986,
#   991: 1986,
#   992: 1986,
#   993: 1986,
#   994: 1986,
#   995: 1986,
#   996: 1986,
#   997: 1986,
#   998: 1986,
#   999: 1986,
#   ...},
#  'teamID': {0: 'ATL',
#   1: 'ATL',
#   2: 'ATL',
#   3: 'ATL',
#   4: 'ATL',
#   5: 'ATL',
#   6: 'ATL',
#   7: 'ATL',
#   8: 'ATL',
#   9: 'ATL',
#   10: 'ATL',
#   11: 'ATL',
#   12: 'ATL',
#   13: 'ATL',
#   14: 'ATL',
#   15: 'ATL',
#   16: 'ATL',
#   17: 'ATL',
#   18: 'ATL',
#   19: 'ATL',
#   20: 'ATL',
#   21: 'ATL',
#   22: 'BAL',
#   23: 'BAL',
#   24: 'BAL',
#   25: 'BAL',
#   26: 'BAL',
#   27: 'BAL',
#   28: 'BAL',
#   29: 'BAL',
#   30: 'BAL',
#   31: 'BAL',
#   32: 'BAL',
#   33: 'BAL',
#   34: 'BAL',
#   35: 'BAL',
#   36: 'BAL',
#   37: 'BAL',
#   38: 'BAL',
#   39: 'BAL',
#   40: 'BAL',
#   41: 'BAL',
#   42: 'BAL',
#   43: 'BAL',
#   44: 'BOS',
#   45: 'BOS',
#   46: 'BOS',
#   47: 'BOS',
#   48: 'BOS',
#   49: 'BOS',
#   50: 'BOS',
#   51: 'BOS',
#   52: 'BOS',
#   53: 'BOS',
#   54: 'BOS',
#   55: 'BOS',
#   56: 'BOS',
#   57: 'BOS',
#   58: 'BOS',
#   59: 'BOS',
#   60: 'BOS',
#   61: 'BOS',
#   62: 'BOS',
#   63: 'BOS',
#   64: 'BOS',
#   65: 'BOS',
#   66: 'BOS',
#   67: 'BOS',
#   68: 'BOS',
#   69: 'CAL',
#   70: 'CAL',
#   71: 'CAL',
#   72: 'CAL',
#   73: 'CAL',
#   74: 'CAL',
#   75: 'CAL',
#   76: 'CAL',
#   77: 'CAL',
#   78: 'CAL',
#   79: 'CAL',
#   80: 'CAL',
#   81: 'CAL',
#   82: 'CAL',
#   83: 'CAL',
#   84: 'CAL',
#   85: 'CAL',
#   86: 'CAL',
#   87: 'CAL',
#   88: 'CAL',
#   89: 'CAL',
#   90: 'CAL',
#   91: 'CAL',
#   92: 'CAL',
#   93: 'CAL',
#   94: 'CAL',
#   95: 'CAL',
#   96: 'CAL',
#   97: 'CHA',
#   98: 'CHA',
#   99: 'CHA',
#   100: 'CHA',
#   101: 'CHA',
#   102: 'CHA',
#   103: 'CHA',
#   104: 'CHA',
#   105: 'CHA',
#   106: 'CHA',
#   107: 'CHA',
#   108: 'CHA',
#   109: 'CHA',
#   110: 'CHA',
#   111: 'CHA',
#   112: 'CHA',
#   113: 'CHA',
#   114: 'CHA',
#   115: 'CHA',
#   116: 'CHA',
#   117: 'CHA',
#   118: 'CHN',
#   119: 'CHN',
#   120: 'CHN',
#   121: 'CHN',
#   122: 'CHN',
#   123: 'CHN',
#   124: 'CHN',
#   125: 'CHN',
#   126: 'CHN',
#   127: 'CHN',
#   128: 'CHN',
#   129: 'CHN',
#   130: 'CHN',
#   131: 'CHN',
#   132: 'CHN',
#   133: 'CHN',
#   134: 'CHN',
#   135: 'CHN',
#   136: 'CHN',
#   137: 'CHN',
#   138: 'CHN',
#   139: 'CHN',
#   140: 'CIN',
#   141: 'CIN',
#   142: 'CIN',
#   143: 'CIN',
#   144: 'CIN',
#   145: 'CIN',
#   146: 'CIN',
#   147: 'CIN',
#   148: 'CIN',
#   149: 'CIN',
#   150: 'CIN',
#   151: 'CIN',
#   152: 'CIN',
#   153: 'CIN',
#   154: 'CIN',
#   155: 'CIN',
#   156: 'CIN',
#   157: 'CIN',
#   158: 'CIN',
#   159: 'CIN',
#   160: 'CIN',
#   161: 'CIN',
#   162: 'CLE',
#   163: 'CLE',
#   164: 'CLE',
#   165: 'CLE',
#   166: 'CLE',
#   167: 'CLE',
#   168: 'CLE',
#   169: 'CLE',
#   170: 'CLE',
#   171: 'CLE',
#   172: 'CLE',
#   173: 'CLE',
#   174: 'CLE',
#   175: 'CLE',
#   176: 'CLE',
#   177: 'CLE',
#   178: 'CLE',
#   179: 'CLE',
#   180: 'CLE',
#   181: 'CLE',
#   182: 'DET',
#   183: 'DET',
#   184: 'DET',
#   185: 'DET',
#   186: 'DET',
#   187: 'DET',
#   188: 'DET',
#   189: 'DET',
#   190: 'DET',
#   191: 'DET',
#   192: 'DET',
#   193: 'DET',
#   194: 'DET',
#   195: 'DET',
#   196: 'DET',
#   197: 'DET',
#   198: 'DET',
#   199: 'DET',
#   200: 'DET',
#   201: 'DET',
#   202: 'HOU',
#   203: 'HOU',
#   204: 'HOU',
#   205: 'HOU',
#   206: 'HOU',
#   207: 'HOU',
#   208: 'HOU',
#   209: 'HOU',
#   210: 'HOU',
#   211: 'HOU',
#   212: 'HOU',
#   213: 'HOU',
#   214: 'HOU',
#   215: 'HOU',
#   216: 'HOU',
#   217: 'HOU',
#   218: 'HOU',
#   219: 'HOU',
#   220: 'HOU',
#   221: 'HOU',
#   222: 'KCA',
#   223: 'KCA',
#   224: 'KCA',
#   225: 'KCA',
#   226: 'KCA',
#   227: 'KCA',
#   228: 'KCA',
#   229: 'KCA',
#   230: 'KCA',
#   231: 'KCA',
#   232: 'KCA',
#   233: 'KCA',
#   234: 'KCA',
#   235: 'KCA',
#   236: 'KCA',
#   237: 'KCA',
#   238: 'KCA',
#   239: 'KCA',
#   240: 'KCA',
#   241: 'KCA',
#   242: 'KCA',
#   243: 'KCA',
#   244: 'LAN',
#   245: 'LAN',
#   246: 'LAN',
#   247: 'LAN',
#   248: 'LAN',
#   249: 'LAN',
#   250: 'LAN',
#   251: 'LAN',
#   252: 'LAN',
#   253: 'LAN',
#   254: 'LAN',
#   255: 'LAN',
#   256: 'LAN',
#   257: 'LAN',
#   258: 'LAN',
#   259: 'LAN',
#   260: 'LAN',
#   261: 'LAN',
#   262: 'LAN',
#   263: 'LAN',
#   264: 'LAN',
#   265: 'LAN',
#   266: 'LAN',
#   267: 'MIN',
#   268: 'MIN',
#   269: 'MIN',
#   270: 'MIN',
#   271: 'MIN',
#   272: 'MIN',
#   273: 'MIN',
#   274: 'MIN',
#   275: 'MIN',
#   276: 'MIN',
#   277: 'MIN',
#   278: 'MIN',
#   279: 'MIN',
#   280: 'MIN',
#   281: 'MIN',
#   282: 'MIN',
#   283: 'MIN',
#   284: 'MIN',
#   285: 'MIN',
#   286: 'ML4',
#   287: 'ML4',
#   288: 'ML4',
#   289: 'ML4',
#   290: 'ML4',
#   291: 'ML4',
#   292: 'ML4',
#   293: 'ML4',
#   294: 'ML4',
#   295: 'ML4',
#   296: 'ML4',
#   297: 'ML4',
#   298: 'ML4',
#   299: 'ML4',
#   300: 'ML4',
#   301: 'ML4',
#   302: 'ML4',
#   303: 'ML4',
#   304: 'ML4',
#   305: 'MON',
#   306: 'MON',
#   307: 'MON',
#   308: 'MON',
#   309: 'MON',
#   310: 'MON',
#   311: 'MON',
#   312: 'MON',
#   313: 'MON',
#   314: 'MON',
#   315: 'MON',
#   316: 'MON',
#   317: 'MON',
#   318: 'MON',
#   319: 'MON',
#   320: 'MON',
#   321: 'MON',
#   322: 'MON',
#   323: 'MON',
#   324: 'MON',
#   325: 'NYA',
#   326: 'NYA',
#   327: 'NYA',
#   328: 'NYA',
#   329: 'NYA',
#   330: 'NYA',
#   331: 'NYA',
#   332: 'NYA',
#   333: 'NYA',
#   334: 'NYA',
#   335: 'NYA',
#   336: 'NYA',
#   337: 'NYA',
#   338: 'NYA',
#   339: 'NYA',
#   340: 'NYA',
#   341: 'NYA',
#   342: 'NYA',
#   343: 'NYA',
#   344: 'NYA',
#   345: 'NYN',
#   346: 'NYN',
#   347: 'NYN',
#   348: 'NYN',
#   349: 'NYN',
#   350: 'NYN',
#   351: 'NYN',
#   352: 'NYN',
#   353: 'NYN',
#   354: 'NYN',
#   355: 'NYN',
#   356: 'NYN',
#   357: 'NYN',
#   358: 'NYN',
#   359: 'NYN',
#   360: 'NYN',
#   361: 'NYN',
#   362: 'NYN',
#   363: 'NYN',
#   364: 'NYN',
#   365: 'NYN',
#   366: 'OAK',
#   367: 'OAK',
#   368: 'OAK',
#   369: 'OAK',
#   370: 'OAK',
#   371: 'OAK',
#   372: 'OAK',
#   373: 'OAK',
#   374: 'OAK',
#   375: 'OAK',
#   376: 'OAK',
#   377: 'OAK',
#   378: 'OAK',
#   379: 'OAK',
#   380: 'OAK',
#   381: 'OAK',
#   382: 'OAK',
#   383: 'OAK',
#   384: 'OAK',
#   385: 'OAK',
#   386: 'OAK',
#   387: 'PHI',
#   388: 'PHI',
#   389: 'PHI',
#   390: 'PHI',
#   391: 'PHI',
#   392: 'PHI',
#   393: 'PHI',
#   394: 'PHI',
#   395: 'PHI',
#   396: 'PHI',
#   397: 'PHI',
#   398: 'PHI',
#   399: 'PHI',
#   400: 'PHI',
#   401: 'PHI',
#   402: 'PHI',
#   403: 'PHI',
#   404: 'PHI',
#   405: 'PHI',
#   406: 'PIT',
#   407: 'PIT',
#   408: 'PIT',
#   409: 'PIT',
#   410: 'PIT',
#   411: 'PIT',
#   412: 'PIT',
#   413: 'PIT',
#   414: 'PIT',
#   415: 'PIT',
#   416: 'PIT',
#   417: 'PIT',
#   418: 'PIT',
#   419: 'PIT',
#   420: 'PIT',
#   421: 'PIT',
#   422: 'PIT',
#   423: 'PIT',
#   424: 'PIT',
#   425: 'SDN',
#   426: 'SDN',
#   427: 'SDN',
#   428: 'SDN',
#   429: 'SDN',
#   430: 'SDN',
#   431: 'SDN',
#   432: 'SDN',
#   433: 'SDN',
#   434: 'SDN',
#   435: 'SDN',
#   436: 'SDN',
#   437: 'SDN',
#   438: 'SDN',
#   439: 'SDN',
#   440: 'SDN',
#   441: 'SDN',
#   442: 'SDN',
#   443: 'SDN',
#   444: 'SDN',
#   445: 'SDN',
#   446: 'SDN',
#   447: 'SEA',
#   448: 'SEA',
#   449: 'SEA',
#   450: 'SEA',
#   451: 'SEA',
#   452: 'SEA',
#   453: 'SEA',
#   454: 'SEA',
#   455: 'SEA',
#   456: 'SEA',
#   457: 'SEA',
#   458: 'SEA',
#   459: 'SEA',
#   460: 'SEA',
#   461: 'SEA',
#   462: 'SEA',
#   463: 'SEA',
#   464: 'SEA',
#   465: 'SFN',
#   466: 'SFN',
#   467: 'SFN',
#   468: 'SFN',
#   469: 'SFN',
#   470: 'SFN',
#   471: 'SFN',
#   472: 'SFN',
#   473: 'SFN',
#   474: 'SFN',
#   475: 'SFN',
#   476: 'SFN',
#   477: 'SFN',
#   478: 'SFN',
#   479: 'SFN',
#   480: 'SFN',
#   481: 'SFN',
#   482: 'SFN',
#   483: 'SFN',
#   484: 'SFN',
#   485: 'SLN',
#   486: 'SLN',
#   487: 'SLN',
#   488: 'SLN',
#   489: 'SLN',
#   490: 'SLN',
#   491: 'SLN',
#   492: 'SLN',
#   493: 'SLN',
#   494: 'SLN',
#   495: 'SLN',
#   496: 'SLN',
#   497: 'SLN',
#   498: 'SLN',
#   499: 'SLN',
#   500: 'SLN',
#   501: 'SLN',
#   502: 'SLN',
#   503: 'SLN',
#   504: 'SLN',
#   505: 'SLN',
#   506: 'SLN',
#   507: 'SLN',
#   508: 'SLN',
#   509: 'SLN',
#   510: 'TEX',
#   511: 'TEX',
#   512: 'TEX',
#   513: 'TEX',
#   514: 'TEX',
#   515: 'TEX',
#   516: 'TEX',
#   517: 'TEX',
#   518: 'TEX',
#   519: 'TEX',
#   520: 'TEX',
#   521: 'TEX',
#   522: 'TEX',
#   523: 'TEX',
#   524: 'TEX',
#   525: 'TEX',
#   526: 'TEX',
#   527: 'TEX',
#   528: 'TEX',
#   529: 'TEX',
#   530: 'TOR',
#   531: 'TOR',
#   532: 'TOR',
#   533: 'TOR',
#   534: 'TOR',
#   535: 'TOR',
#   536: 'TOR',
#   537: 'TOR',
#   538: 'TOR',
#   539: 'TOR',
#   540: 'TOR',
#   541: 'TOR',
#   542: 'TOR',
#   543: 'TOR',
#   544: 'TOR',
#   545: 'TOR',
#   546: 'TOR',
#   547: 'TOR',
#   548: 'TOR',
#   549: 'TOR',
#   550: 'ATL',
#   551: 'ATL',
#   552: 'ATL',
#   553: 'ATL',
#   554: 'ATL',
#   555: 'ATL',
#   556: 'ATL',
#   557: 'ATL',
#   558: 'ATL',
#   559: 'ATL',
#   560: 'ATL',
#   561: 'ATL',
#   562: 'ATL',
#   563: 'ATL',
#   564: 'ATL',
#   565: 'ATL',
#   566: 'ATL',
#   567: 'ATL',
#   568: 'ATL',
#   569: 'ATL',
#   570: 'ATL',
#   571: 'ATL',
#   572: 'ATL',
#   573: 'ATL',
#   574: 'ATL',
#   575: 'ATL',
#   576: 'ATL',
#   577: 'ATL',
#   578: 'ATL',
#   579: 'BAL',
#   580: 'BAL',
#   581: 'BAL',
#   582: 'BAL',
#   583: 'BAL',
#   584: 'BAL',
#   585: 'BAL',
#   586: 'BAL',
#   587: 'BAL',
#   588: 'BAL',
#   589: 'BAL',
#   590: 'BAL',
#   591: 'BAL',
#   592: 'BAL',
#   593: 'BAL',
#   594: 'BAL',
#   595: 'BAL',
#   596: 'BAL',
#   597: 'BAL',
#   598: 'BAL',
#   599: 'BAL',
#   600: 'BAL',
#   601: 'BAL',
#   602: 'BAL',
#   603: 'BAL',
#   604: 'BAL',
#   605: 'BAL',
#   606: 'BAL',
#   607: 'BAL',
#   608: 'BOS',
#   609: 'BOS',
#   610: 'BOS',
#   611: 'BOS',
#   612: 'BOS',
#   613: 'BOS',
#   614: 'BOS',
#   615: 'BOS',
#   616: 'BOS',
#   617: 'BOS',
#   618: 'BOS',
#   619: 'BOS',
#   620: 'BOS',
#   621: 'BOS',
#   622: 'BOS',
#   623: 'BOS',
#   624: 'BOS',
#   625: 'BOS',
#   626: 'BOS',
#   627: 'BOS',
#   628: 'BOS',
#   629: 'BOS',
#   630: 'BOS',
#   631: 'BOS',
#   632: 'BOS',
#   633: 'BOS',
#   634: 'BOS',
#   635: 'BOS',
#   636: 'BOS',
#   637: 'CAL',
#   638: 'CAL',
#   639: 'CAL',
#   640: 'CAL',
#   641: 'CAL',
#   642: 'CAL',
#   643: 'CAL',
#   644: 'CAL',
#   645: 'CAL',
#   646: 'CAL',
#   647: 'CAL',
#   648: 'CAL',
#   649: 'CAL',
#   650: 'CAL',
#   651: 'CAL',
#   652: 'CAL',
#   653: 'CAL',
#   654: 'CAL',
#   655: 'CAL',
#   656: 'CAL',
#   657: 'CAL',
#   658: 'CAL',
#   659: 'CAL',
#   660: 'CAL',
#   661: 'CAL',
#   662: 'CAL',
#   663: 'CAL',
#   664: 'CAL',
#   665: 'CAL',
#   666: 'CHA',
#   667: 'CHA',
#   668: 'CHA',
#   669: 'CHA',
#   670: 'CHA',
#   671: 'CHA',
#   672: 'CHA',
#   673: 'CHA',
#   674: 'CHA',
#   675: 'CHA',
#   676: 'CHA',
#   677: 'CHA',
#   678: 'CHA',
#   679: 'CHA',
#   680: 'CHA',
#   681: 'CHA',
#   682: 'CHA',
#   683: 'CHA',
#   684: 'CHA',
#   685: 'CHA',
#   686: 'CHA',
#   687: 'CHA',
#   688: 'CHA',
#   689: 'CHA',
#   690: 'CHA',
#   691: 'CHA',
#   692: 'CHA',
#   693: 'CHA',
#   694: 'CHA',
#   695: 'CHA',
#   696: 'CHA',
#   697: 'CHN',
#   698: 'CHN',
#   699: 'CHN',
#   700: 'CHN',
#   701: 'CHN',
#   702: 'CHN',
#   703: 'CHN',
#   704: 'CHN',
#   705: 'CHN',
#   706: 'CHN',
#   707: 'CHN',
#   708: 'CHN',
#   709: 'CHN',
#   710: 'CHN',
#   711: 'CHN',
#   712: 'CHN',
#   713: 'CHN',
#   714: 'CHN',
#   715: 'CHN',
#   716: 'CHN',
#   717: 'CHN',
#   718: 'CHN',
#   719: 'CHN',
#   720: 'CHN',
#   721: 'CHN',
#   722: 'CHN',
#   723: 'CHN',
#   724: 'CHN',
#   725: 'CHN',
#   726: 'CHN',
#   727: 'CHN',
#   728: 'CIN',
#   729: 'CIN',
#   730: 'CIN',
#   731: 'CIN',
#   732: 'CIN',
#   733: 'CIN',
#   734: 'CIN',
#   735: 'CIN',
#   736: 'CIN',
#   737: 'CIN',
#   738: 'CIN',
#   739: 'CIN',
#   740: 'CIN',
#   741: 'CIN',
#   742: 'CIN',
#   743: 'CIN',
#   744: 'CIN',
#   745: 'CIN',
#   746: 'CIN',
#   747: 'CIN',
#   748: 'CIN',
#   749: 'CIN',
#   750: 'CIN',
#   751: 'CIN',
#   752: 'CIN',
#   753: 'CIN',
#   754: 'CIN',
#   755: 'CIN',
#   756: 'CIN',
#   757: 'CIN',
#   758: 'CLE',
#   759: 'CLE',
#   760: 'CLE',
#   761: 'CLE',
#   762: 'CLE',
#   763: 'CLE',
#   764: 'CLE',
#   765: 'CLE',
#   766: 'CLE',
#   767: 'CLE',
#   768: 'CLE',
#   769: 'CLE',
#   770: 'CLE',
#   771: 'CLE',
#   772: 'CLE',
#   773: 'CLE',
#   774: 'CLE',
#   775: 'CLE',
#   776: 'CLE',
#   777: 'CLE',
#   778: 'CLE',
#   779: 'CLE',
#   780: 'CLE',
#   781: 'CLE',
#   782: 'CLE',
#   783: 'CLE',
#   784: 'CLE',
#   785: 'CLE',
#   786: 'CLE',
#   787: 'CLE',
#   788: 'CLE',
#   789: 'DET',
#   790: 'DET',
#   791: 'DET',
#   792: 'DET',
#   793: 'DET',
#   794: 'DET',
#   795: 'DET',
#   796: 'DET',
#   797: 'DET',
#   798: 'DET',
#   799: 'DET',
#   800: 'DET',
#   801: 'DET',
#   802: 'DET',
#   803: 'DET',
#   804: 'DET',
#   805: 'DET',
#   806: 'DET',
#   807: 'DET',
#   808: 'DET',
#   809: 'DET',
#   810: 'DET',
#   811: 'DET',
#   812: 'DET',
#   813: 'DET',
#   814: 'DET',
#   815: 'DET',
#   816: 'HOU',
#   817: 'HOU',
#   818: 'HOU',
#   819: 'HOU',
#   820: 'HOU',
#   821: 'HOU',
#   822: 'HOU',
#   823: 'HOU',
#   824: 'HOU',
#   825: 'HOU',
#   826: 'HOU',
#   827: 'HOU',
#   828: 'HOU',
#   829: 'HOU',
#   830: 'HOU',
#   831: 'HOU',
#   832: 'HOU',
#   833: 'HOU',
#   834: 'HOU',
#   835: 'HOU',
#   836: 'HOU',
#   837: 'HOU',
#   838: 'HOU',
#   839: 'HOU',
#   840: 'KCA',
#   841: 'KCA',
#   842: 'KCA',
#   843: 'KCA',
#   844: 'KCA',
#   845: 'KCA',
#   846: 'KCA',
#   847: 'KCA',
#   848: 'KCA',
#   849: 'KCA',
#   850: 'KCA',
#   851: 'KCA',
#   852: 'KCA',
#   853: 'KCA',
#   854: 'KCA',
#   855: 'KCA',
#   856: 'KCA',
#   857: 'KCA',
#   858: 'KCA',
#   859: 'KCA',
#   860: 'KCA',
#   861: 'KCA',
#   862: 'KCA',
#   863: 'KCA',
#   864: 'KCA',
#   865: 'KCA',
#   866: 'KCA',
#   867: 'KCA',
#   868: 'LAN',
#   869: 'LAN',
#   870: 'LAN',
#   871: 'LAN',
#   872: 'LAN',
#   873: 'LAN',
#   874: 'LAN',
#   875: 'LAN',
#   876: 'LAN',
#   877: 'LAN',
#   878: 'LAN',
#   879: 'LAN',
#   880: 'LAN',
#   881: 'LAN',
#   882: 'LAN',
#   883: 'LAN',
#   884: 'LAN',
#   885: 'LAN',
#   886: 'LAN',
#   887: 'LAN',
#   888: 'LAN',
#   889: 'LAN',
#   890: 'LAN',
#   891: 'LAN',
#   892: 'LAN',
#   893: 'LAN',
#   894: 'LAN',
#   895: 'LAN',
#   896: 'LAN',
#   897: 'LAN',
#   898: 'LAN',
#   899: 'LAN',
#   900: 'MIN',
#   901: 'MIN',
#   902: 'MIN',
#   903: 'MIN',
#   904: 'MIN',
#   905: 'MIN',
#   906: 'MIN',
#   907: 'MIN',
#   908: 'MIN',
#   909: 'MIN',
#   910: 'MIN',
#   911: 'MIN',
#   912: 'MIN',
#   913: 'MIN',
#   914: 'MIN',
#   915: 'MIN',
#   916: 'MIN',
#   917: 'MIN',
#   918: 'MIN',
#   919: 'MIN',
#   920: 'MIN',
#   921: 'MIN',
#   922: 'ML4',
#   923: 'ML4',
#   924: 'ML4',
#   925: 'ML4',
#   926: 'ML4',
#   927: 'ML4',
#   928: 'ML4',
#   929: 'ML4',
#   930: 'ML4',
#   931: 'ML4',
#   932: 'ML4',
#   933: 'ML4',
#   934: 'ML4',
#   935: 'ML4',
#   936: 'ML4',
#   937: 'ML4',
#   938: 'ML4',
#   939: 'ML4',
#   940: 'ML4',
#   941: 'ML4',
#   942: 'ML4',
#   943: 'ML4',
#   944: 'ML4',
#   945: 'ML4',
#   946: 'ML4',
#   947: 'ML4',
#   948: 'ML4',
#   949: 'ML4',
#   950: 'MON',
#   951: 'MON',
#   952: 'MON',
#   953: 'MON',
#   954: 'MON',
#   955: 'MON',
#   956: 'MON',
#   957: 'MON',
#   958: 'MON',
#   959: 'MON',
#   960: 'MON',
#   961: 'MON',
#   962: 'MON',
#   963: 'MON',
#   964: 'MON',
#   965: 'MON',
#   966: 'MON',
#   967: 'MON',
#   968: 'MON',
#   969: 'MON',
#   970: 'MON',
#   971: 'MON',
#   972: 'MON',
#   973: 'MON',
#   974: 'MON',
#   975: 'MON',
#   976: 'MON',
#   977: 'MON',
#   978: 'MON',
#   979: 'MON',
#   980: 'MON',
#   981: 'MON',
#   982: 'NYA',
#   983: 'NYA',
#   984: 'NYA',
#   985: 'NYA',
#   986: 'NYA',
#   987: 'NYA',
#   988: 'NYA',
#   989: 'NYA',
#   990: 'NYA',
#   991: 'NYA',
#   992: 'NYA',
#   993: 'NYA',
#   994: 'NYA',
#   995: 'NYA',
#   996: 'NYA',
#   997: 'NYA',
#   998: 'NYA',
#   999: 'NYA',
#   ...},
#  'lgID': {0: 'NL',
#   1: 'NL',
#   2: 'NL',
#   3: 'NL',
#   4: 'NL',
#   5: 'NL',
#   6: 'NL',
#   7: 'NL',
#   8: 'NL',
#   9: 'NL',
#   10: 'NL',
#   11: 'NL',
#   12: 'NL',
#   13: 'NL',
#   14: 'NL',
#   15: 'NL',
#   16: 'NL',
#   17: 'NL',
#   18: 'NL',
#   19: 'NL',
#   20: 'NL',
#   21: 'NL',
#   22: 'AL',
#   23: 'AL',
#   24: 'AL',
#   25: 'AL',
#   26: 'AL',
#   27: 'AL',
#   28: 'AL',
#   29: 'AL',
#   30: 'AL',
#   31: 'AL',
#   32: 'AL',
#   33: 'AL',
#   34: 'AL',
#   35: 'AL',
#   36: 'AL',
#   37: 'AL',
#   38: 'AL',
#   39: 'AL',
#   40: 'AL',
#   41: 'AL',
#   42: 'AL',
#   43: 'AL',
#   44: 'AL',
#   45: 'AL',
#   46: 'AL',
#   47: 'AL',
#   48: 'AL',
#   49: 'AL',
#   50: 'AL',
#   51: 'AL',
#   52: 'AL',
#   53: 'AL',
#   54: 'AL',
#   55: 'AL',
#   56: 'AL',
#   57: 'AL',
#   58: 'AL',
#   59: 'AL',
#   60: 'AL',
#   61: 'AL',
#   62: 'AL',
#   63: 'AL',
#   64: 'AL',
#   65: 'AL',
#   66: 'AL',
#   67: 'AL',
#   68: 'AL',
#   69: 'AL',
#   70: 'AL',
#   71: 'AL',
#   72: 'AL',
#   73: 'AL',
#   74: 'AL',
#   75: 'AL',
#   76: 'AL',
#   77: 'AL',
#   78: 'AL',
#   79: 'AL',
#   80: 'AL',
#   81: 'AL',
#   82: 'AL',
#   83: 'AL',
#   84: 'AL',
#   85: 'AL',
#   86: 'AL',
#   87: 'AL',
#   88: 'AL',
#   89: 'AL',
#   90: 'AL',
#   91: 'AL',
#   92: 'AL',
#   93: 'AL',
#   94: 'AL',
#   95: 'AL',
#   96: 'AL',
#   97: 'AL',
#   98: 'AL',
#   99: 'AL',
#   100: 'AL',
#   101: 'AL',
#   102: 'AL',
#   103: 'AL',
#   104: 'AL',
#   105: 'AL',
#   106: 'AL',
#   107: 'AL',
#   108: 'AL',
#   109: 'AL',
#   110: 'AL',
#   111: 'AL',
#   112: 'AL',
#   113: 'AL',
#   114: 'AL',
#   115: 'AL',
#   116: 'AL',
#   117: 'AL',
#   118: 'NL',
#   119: 'NL',
#   120: 'NL',
#   121: 'NL',
#   122: 'NL',
#   123: 'NL',
#   124: 'NL',
#   125: 'NL',
#   126: 'NL',
#   127: 'NL',
#   128: 'NL',
#   129: 'NL',
#   130: 'NL',
#   131: 'NL',
#   132: 'NL',
#   133: 'NL',
#   134: 'NL',
#   135: 'NL',
#   136: 'NL',
#   137: 'NL',
#   138: 'NL',
#   139: 'NL',
#   140: 'NL',
#   141: 'NL',
#   142: 'NL',
#   143: 'NL',
#   144: 'NL',
#   145: 'NL',
#   146: 'NL',
#   147: 'NL',
#   148: 'NL',
#   149: 'NL',
#   150: 'NL',
#   151: 'NL',
#   152: 'NL',
#   153: 'NL',
#   154: 'NL',
#   155: 'NL',
#   156: 'NL',
#   157: 'NL',
#   158: 'NL',
#   159: 'NL',
#   160: 'NL',
#   161: 'NL',
#   162: 'AL',
#   163: 'AL',
#   164: 'AL',
#   165: 'AL',
#   166: 'AL',
#   167: 'AL',
#   168: 'AL',
#   169: 'AL',
#   170: 'AL',
#   171: 'AL',
#   172: 'AL',
#   173: 'AL',
#   174: 'AL',
#   175: 'AL',
#   176: 'AL',
#   177: 'AL',
#   178: 'AL',
#   179: 'AL',
#   180: 'AL',
#   181: 'AL',
#   182: 'AL',
#   183: 'AL',
#   184: 'AL',
#   185: 'AL',
#   186: 'AL',
#   187: 'AL',
#   188: 'AL',
#   189: 'AL',
#   190: 'AL',
#   191: 'AL',
#   192: 'AL',
#   193: 'AL',
#   194: 'AL',
#   195: 'AL',
#   196: 'AL',
#   197: 'AL',
#   198: 'AL',
#   199: 'AL',
#   200: 'AL',
#   201: 'AL',
#   202: 'NL',
#   203: 'NL',
#   204: 'NL',
#   205: 'NL',
#   206: 'NL',
#   207: 'NL',
#   208: 'NL',
#   209: 'NL',
#   210: 'NL',
#   211: 'NL',
#   212: 'NL',
#   213: 'NL',
#   214: 'NL',
#   215: 'NL',
#   216: 'NL',
#   217: 'NL',
#   218: 'NL',
#   219: 'NL',
#   220: 'NL',
#   221: 'NL',
#   222: 'AL',
#   223: 'AL',
#   224: 'AL',
#   225: 'AL',
#   226: 'AL',
#   227: 'AL',
#   228: 'AL',
#   229: 'AL',
#   230: 'AL',
#   231: 'AL',
#   232: 'AL',
#   233: 'AL',
#   234: 'AL',
#   235: 'AL',
#   236: 'AL',
#   237: 'AL',
#   238: 'AL',
#   239: 'AL',
#   240: 'AL',
#   241: 'AL',
#   242: 'AL',
#   243: 'AL',
#   244: 'NL',
#   245: 'NL',
#   246: 'NL',
#   247: 'NL',
#   248: 'NL',
#   249: 'NL',
#   250: 'NL',
#   251: 'NL',
#   252: 'NL',
#   253: 'NL',
#   254: 'NL',
#   255: 'NL',
#   256: 'NL',
#   257: 'NL',
#   258: 'NL',
#   259: 'NL',
#   260: 'NL',
#   261: 'NL',
#   262: 'NL',
#   263: 'NL',
#   264: 'NL',
#   265: 'NL',
#   266: 'NL',
#   267: 'AL',
#   268: 'AL',
#   269: 'AL',
#   270: 'AL',
#   271: 'AL',
#   272: 'AL',
#   273: 'AL',
#   274: 'AL',
#   275: 'AL',
#   276: 'AL',
#   277: 'AL',
#   278: 'AL',
#   279: 'AL',
#   280: 'AL',
#   281: 'AL',
#   282: 'AL',
#   283: 'AL',
#   284: 'AL',
#   285: 'AL',
#   286: 'AL',
#   287: 'AL',
#   288: 'AL',
#   289: 'AL',
#   290: 'AL',
#   291: 'AL',
#   292: 'AL',
#   293: 'AL',
#   294: 'AL',
#   295: 'AL',
#   296: 'AL',
#   297: 'AL',
#   298: 'AL',
#   299: 'AL',
#   300: 'AL',
#   301: 'AL',
#   302: 'AL',
#   303: 'AL',
#   304: 'AL',
#   305: 'NL',
#   306: 'NL',
#   307: 'NL',
#   308: 'NL',
#   309: 'NL',
#   310: 'NL',
#   311: 'NL',
#   312: 'NL',
#   313: 'NL',
#   314: 'NL',
#   315: 'NL',
#   316: 'NL',
#   317: 'NL',
#   318: 'NL',
#   319: 'NL',
#   320: 'NL',
#   321: 'NL',
#   322: 'NL',
#   323: 'NL',
#   324: 'NL',
#   325: 'AL',
#   326: 'AL',
#   327: 'AL',
#   328: 'AL',
#   329: 'AL',
#   330: 'AL',
#   331: 'AL',
#   332: 'AL',
#   333: 'AL',
#   334: 'AL',
#   335: 'AL',
#   336: 'AL',
#   337: 'AL',
#   338: 'AL',
#   339: 'AL',
#   340: 'AL',
#   341: 'AL',
#   342: 'AL',
#   343: 'AL',
#   344: 'AL',
#   345: 'NL',
#   346: 'NL',
#   347: 'NL',
#   348: 'NL',
#   349: 'NL',
#   350: 'NL',
#   351: 'NL',
#   352: 'NL',
#   353: 'NL',
#   354: 'NL',
#   355: 'NL',
#   356: 'NL',
#   357: 'NL',
#   358: 'NL',
#   359: 'NL',
#   360: 'NL',
#   361: 'NL',
#   362: 'NL',
#   363: 'NL',
#   364: 'NL',
#   365: 'NL',
#   366: 'AL',
#   367: 'AL',
#   368: 'AL',
#   369: 'AL',
#   370: 'AL',
#   371: 'AL',
#   372: 'AL',
#   373: 'AL',
#   374: 'AL',
#   375: 'AL',
#   376: 'AL',
#   377: 'AL',
#   378: 'AL',
#   379: 'AL',
#   380: 'AL',
#   381: 'AL',
#   382: 'AL',
#   383: 'AL',
#   384: 'AL',
#   385: 'AL',
#   386: 'AL',
#   387: 'NL',
#   388: 'NL',
#   389: 'NL',
#   390: 'NL',
#   391: 'NL',
#   392: 'NL',
#   393: 'NL',
#   394: 'NL',
#   395: 'NL',
#   396: 'NL',
#   397: 'NL',
#   398: 'NL',
#   399: 'NL',
#   400: 'NL',
#   401: 'NL',
#   402: 'NL',
#   403: 'NL',
#   404: 'NL',
#   405: 'NL',
#   406: 'NL',
#   407: 'NL',
#   408: 'NL',
#   409: 'NL',
#   410: 'NL',
#   411: 'NL',
#   412: 'NL',
#   413: 'NL',
#   414: 'NL',
#   415: 'NL',
#   416: 'NL',
#   417: 'NL',
#   418: 'NL',
#   419: 'NL',
#   420: 'NL',
#   421: 'NL',
#   422: 'NL',
#   423: 'NL',
#   424: 'NL',
#   425: 'NL',
#   426: 'NL',
#   427: 'NL',
#   428: 'NL',
#   429: 'NL',
#   430: 'NL',
#   431: 'NL',
#   432: 'NL',
#   433: 'NL',
#   434: 'NL',
#   435: 'NL',
#   436: 'NL',
#   437: 'NL',
#   438: 'NL',
#   439: 'NL',
#   440: 'NL',
#   441: 'NL',
#   442: 'NL',
#   443: 'NL',
#   444: 'NL',
#   445: 'NL',
#   446: 'NL',
#   447: 'AL',
#   448: 'AL',
#   449: 'AL',
#   450: 'AL',
#   451: 'AL',
#   452: 'AL',
#   453: 'AL',
#   454: 'AL',
#   455: 'AL',
#   456: 'AL',
#   457: 'AL',
#   458: 'AL',
#   459: 'AL',
#   460: 'AL',
#   461: 'AL',
#   462: 'AL',
#   463: 'AL',
#   464: 'AL',
#   465: 'NL',
#   466: 'NL',
#   467: 'NL',
#   468: 'NL',
#   469: 'NL',
#   470: 'NL',
#   471: 'NL',
#   472: 'NL',
#   473: 'NL',
#   474: 'NL',
#   475: 'NL',
#   476: 'NL',
#   477: 'NL',
#   478: 'NL',
#   479: 'NL',
#   480: 'NL',
#   481: 'NL',
#   482: 'NL',
#   483: 'NL',
#   484: 'NL',
#   485: 'NL',
#   486: 'NL',
#   487: 'NL',
#   488: 'NL',
#   489: 'NL',
#   490: 'NL',
#   491: 'NL',
#   492: 'NL',
#   493: 'NL',
#   494: 'NL',
#   495: 'NL',
#   496: 'NL',
#   497: 'NL',
#   498: 'NL',
#   499: 'NL',
#   500: 'NL',
#   501: 'NL',
#   502: 'NL',
#   503: 'NL',
#   504: 'NL',
#   505: 'NL',
#   506: 'NL',
#   507: 'NL',
#   508: 'NL',
#   509: 'NL',
#   510: 'AL',
#   511: 'AL',
#   512: 'AL',
#   513: 'AL',
#   514: 'AL',
#   515: 'AL',
#   516: 'AL',
#   517: 'AL',
#   518: 'AL',
#   519: 'AL',
#   520: 'AL',
#   521: 'AL',
#   522: 'AL',
#   523: 'AL',
#   524: 'AL',
#   525: 'AL',
#   526: 'AL',
#   527: 'AL',
#   528: 'AL',
#   529: 'AL',
#   530: 'AL',
#   531: 'AL',
#   532: 'AL',
#   533: 'AL',
#   534: 'AL',
#   535: 'AL',
#   536: 'AL',
#   537: 'AL',
#   538: 'AL',
#   539: 'AL',
#   540: 'AL',
#   541: 'AL',
#   542: 'AL',
#   543: 'AL',
#   544: 'AL',
#   545: 'AL',
#   546: 'AL',
#   547: 'AL',
#   548: 'AL',
#   549: 'AL',
#   550: 'NL',
#   551: 'NL',
#   552: 'NL',
#   553: 'NL',
#   554: 'NL',
#   555: 'NL',
#   556: 'NL',
#   557: 'NL',
#   558: 'NL',
#   559: 'NL',
#   560: 'NL',
#   561: 'NL',
#   562: 'NL',
#   563: 'NL',
#   564: 'NL',
#   565: 'NL',
#   566: 'NL',
#   567: 'NL',
#   568: 'NL',
#   569: 'NL',
#   570: 'NL',
#   571: 'NL',
#   572: 'NL',
#   573: 'NL',
#   574: 'NL',
#   575: 'NL',
#   576: 'NL',
#   577: 'NL',
#   578: 'NL',
#   579: 'AL',
#   580: 'AL',
#   581: 'AL',
#   582: 'AL',
#   583: 'AL',
#   584: 'AL',
#   585: 'AL',
#   586: 'AL',
#   587: 'AL',
#   588: 'AL',
#   589: 'AL',
#   590: 'AL',
#   591: 'AL',
#   592: 'AL',
#   593: 'AL',
#   594: 'AL',
#   595: 'AL',
#   596: 'AL',
#   597: 'AL',
#   598: 'AL',
#   599: 'AL',
#   600: 'AL',
#   601: 'AL',
#   602: 'AL',
#   603: 'AL',
#   604: 'AL',
#   605: 'AL',
#   606: 'AL',
#   607: 'AL',
#   608: 'AL',
#   609: 'AL',
#   610: 'AL',
#   611: 'AL',
#   612: 'AL',
#   613: 'AL',
#   614: 'AL',
#   615: 'AL',
#   616: 'AL',
#   617: 'AL',
#   618: 'AL',
#   619: 'AL',
#   620: 'AL',
#   621: 'AL',
#   622: 'AL',
#   623: 'AL',
#   624: 'AL',
#   625: 'AL',
#   626: 'AL',
#   627: 'AL',
#   628: 'AL',
#   629: 'AL',
#   630: 'AL',
#   631: 'AL',
#   632: 'AL',
#   633: 'AL',
#   634: 'AL',
#   635: 'AL',
#   636: 'AL',
#   637: 'AL',
#   638: 'AL',
#   639: 'AL',
#   640: 'AL',
#   641: 'AL',
#   642: 'AL',
#   643: 'AL',
#   644: 'AL',
#   645: 'AL',
#   646: 'AL',
#   647: 'AL',
#   648: 'AL',
#   649: 'AL',
#   650: 'AL',
#   651: 'AL',
#   652: 'AL',
#   653: 'AL',
#   654: 'AL',
#   655: 'AL',
#   656: 'AL',
#   657: 'AL',
#   658: 'AL',
#   659: 'AL',
#   660: 'AL',
#   661: 'AL',
#   662: 'AL',
#   663: 'AL',
#   664: 'AL',
#   665: 'AL',
#   666: 'AL',
#   667: 'AL',
#   668: 'AL',
#   669: 'AL',
#   670: 'AL',
#   671: 'AL',
#   672: 'AL',
#   673: 'AL',
#   674: 'AL',
#   675: 'AL',
#   676: 'AL',
#   677: 'AL',
#   678: 'AL',
#   679: 'AL',
#   680: 'AL',
#   681: 'AL',
#   682: 'AL',
#   683: 'AL',
#   684: 'AL',
#   685: 'AL',
#   686: 'AL',
#   687: 'AL',
#   688: 'AL',
#   689: 'AL',
#   690: 'AL',
#   691: 'AL',
#   692: 'AL',
#   693: 'AL',
#   694: 'AL',
#   695: 'AL',
#   696: 'AL',
#   697: 'NL',
#   698: 'NL',
#   699: 'NL',
#   700: 'NL',
#   701: 'NL',
#   702: 'NL',
#   703: 'NL',
#   704: 'NL',
#   705: 'NL',
#   706: 'NL',
#   707: 'NL',
#   708: 'NL',
#   709: 'NL',
#   710: 'NL',
#   711: 'NL',
#   712: 'NL',
#   713: 'NL',
#   714: 'NL',
#   715: 'NL',
#   716: 'NL',
#   717: 'NL',
#   718: 'NL',
#   719: 'NL',
#   720: 'NL',
#   721: 'NL',
#   722: 'NL',
#   723: 'NL',
#   724: 'NL',
#   725: 'NL',
#   726: 'NL',
#   727: 'NL',
#   728: 'NL',
#   729: 'NL',
#   730: 'NL',
#   731: 'NL',
#   732: 'NL',
#   733: 'NL',
#   734: 'NL',
#   735: 'NL',
#   736: 'NL',
#   737: 'NL',
#   738: 'NL',
#   739: 'NL',
#   740: 'NL',
#   741: 'NL',
#   742: 'NL',
#   743: 'NL',
#   744: 'NL',
#   745: 'NL',
#   746: 'NL',
#   747: 'NL',
#   748: 'NL',
#   749: 'NL',
#   750: 'NL',
#   751: 'NL',
#   752: 'NL',
#   753: 'NL',
#   754: 'NL',
#   755: 'NL',
#   756: 'NL',
#   757: 'NL',
#   758: 'AL',
#   759: 'AL',
#   760: 'AL',
#   761: 'AL',
#   762: 'AL',
#   763: 'AL',
#   764: 'AL',
#   765: 'AL',
#   766: 'AL',
#   767: 'AL',
#   768: 'AL',
#   769: 'AL',
#   770: 'AL',
#   771: 'AL',
#   772: 'AL',
#   773: 'AL',
#   774: 'AL',
#   775: 'AL',
#   776: 'AL',
#   777: 'AL',
#   778: 'AL',
#   779: 'AL',
#   780: 'AL',
#   781: 'AL',
#   782: 'AL',
#   783: 'AL',
#   784: 'AL',
#   785: 'AL',
#   786: 'AL',
#   787: 'AL',
#   788: 'AL',
#   789: 'AL',
#   790: 'AL',
#   791: 'AL',
#   792: 'AL',
#   793: 'AL',
#   794: 'AL',
#   795: 'AL',
#   796: 'AL',
#   797: 'AL',
#   798: 'AL',
#   799: 'AL',
#   800: 'AL',
#   801: 'AL',
#   802: 'AL',
#   803: 'AL',
#   804: 'AL',
#   805: 'AL',
#   806: 'AL',
#   807: 'AL',
#   808: 'AL',
#   809: 'AL',
#   810: 'AL',
#   811: 'AL',
#   812: 'AL',
#   813: 'AL',
#   814: 'AL',
#   815: 'AL',
#   816: 'NL',
#   817: 'NL',
#   818: 'NL',
#   819: 'NL',
#   820: 'NL',
#   821: 'NL',
#   822: 'NL',
#   823: 'NL',
#   824: 'NL',
#   825: 'NL',
#   826: 'NL',
#   827: 'NL',
#   828: 'NL',
#   829: 'NL',
#   830: 'NL',
#   831: 'NL',
#   832: 'NL',
#   833: 'NL',
#   834: 'NL',
#   835: 'NL',
#   836: 'NL',
#   837: 'NL',
#   838: 'NL',
#   839: 'NL',
#   840: 'AL',
#   841: 'AL',
#   842: 'AL',
#   843: 'AL',
#   844: 'AL',
#   845: 'AL',
#   846: 'AL',
#   847: 'AL',
#   848: 'AL',
#   849: 'AL',
#   850: 'AL',
#   851: 'AL',
#   852: 'AL',
#   853: 'AL',
#   854: 'AL',
#   855: 'AL',
#   856: 'AL',
#   857: 'AL',
#   858: 'AL',
#   859: 'AL',
#   860: 'AL',
#   861: 'AL',
#   862: 'AL',
#   863: 'AL',
#   864: 'AL',
#   865: 'AL',
#   866: 'AL',
#   867: 'AL',
#   868: 'NL',
#   869: 'NL',
#   870: 'NL',
#   871: 'NL',
#   872: 'NL',
#   873: 'NL',
#   874: 'NL',
#   875: 'NL',
#   876: 'NL',
#   877: 'NL',
#   878: 'NL',
#   879: 'NL',
#   880: 'NL',
#   881: 'NL',
#   882: 'NL',
#   883: 'NL',
#   884: 'NL',
#   885: 'NL',
#   886: 'NL',
#   887: 'NL',
#   888: 'NL',
#   889: 'NL',
#   890: 'NL',
#   891: 'NL',
#   892: 'NL',
#   893: 'NL',
#   894: 'NL',
#   895: 'NL',
#   896: 'NL',
#   897: 'NL',
#   898: 'NL',
#   899: 'NL',
#   900: 'AL',
#   901: 'AL',
#   902: 'AL',
#   903: 'AL',
#   904: 'AL',
#   905: 'AL',
#   906: 'AL',
#   907: 'AL',
#   908: 'AL',
#   909: 'AL',
#   910: 'AL',
#   911: 'AL',
#   912: 'AL',
#   913: 'AL',
#   914: 'AL',
#   915: 'AL',
#   916: 'AL',
#   917: 'AL',
#   918: 'AL',
#   919: 'AL',
#   920: 'AL',
#   921: 'AL',
#   922: 'AL',
#   923: 'AL',
#   924: 'AL',
#   925: 'AL',
#   926: 'AL',
#   927: 'AL',
#   928: 'AL',
#   929: 'AL',
#   930: 'AL',
#   931: 'AL',
#   932: 'AL',
#   933: 'AL',
#   934: 'AL',
#   935: 'AL',
#   936: 'AL',
#   937: 'AL',
#   938: 'AL',
#   939: 'AL',
#   940: 'AL',
#   941: 'AL',
#   942: 'AL',
#   943: 'AL',
#   944: 'AL',
#   945: 'AL',
#   946: 'AL',
#   947: 'AL',
#   948: 'AL',
#   949: 'AL',
#   950: 'NL',
#   951: 'NL',
#   952: 'NL',
#   953: 'NL',
#   954: 'NL',
#   955: 'NL',
#   956: 'NL',
#   957: 'NL',
#   958: 'NL',
#   959: 'NL',
#   960: 'NL',
#   961: 'NL',
#   962: 'NL',
#   963: 'NL',
#   964: 'NL',
#   965: 'NL',
#   966: 'NL',
#   967: 'NL',
#   968: 'NL',
#   969: 'NL',
#   970: 'NL',
#   971: 'NL',
#   972: 'NL',
#   973: 'NL',
#   974: 'NL',
#   975: 'NL',
#   976: 'NL',
#   977: 'NL',
#   978: 'NL',
#   979: 'NL',
#   980: 'NL',
#   981: 'NL',
#   982: 'AL',
#   983: 'AL',
#   984: 'AL',
#   985: 'AL',
#   986: 'AL',
#   987: 'AL',
#   988: 'AL',
#   989: 'AL',
#   990: 'AL',
#   991: 'AL',
#   992: 'AL',
#   993: 'AL',
#   994: 'AL',
#   995: 'AL',
#   996: 'AL',
#   997: 'AL',
#   998: 'AL',
#   999: 'AL',
#   ...},
#  'playerID': {0: 'barkele01',
#   1: 'bedrost01',
#   2: 'benedbr01',
#   3: 'campri01',
#   4: 'ceronri01',
#   5: 'chambch01',
#   6: 'dedmoje01',
#   7: 'forstte01',
#   8: 'garbege01',
#   9: 'harpete01',
#   10: 'hornebo01',
#   11: 'hubbagl01',
#   12: 'mahleri01',
#   13: 'mcmurcr01',
#   14: 'mumphje01',
#   15: 'murphda05',
#   16: 'oberkke01',
#   17: 'perezpa01',
#   18: 'perryge01',
#   19: 'ramirra01',
#   20: 'suttebr01',
#   21: 'washicl01',
#   22: 'boddimi01',
#   23: 'dauerri01',
#   24: 'davisst02',
#   25: 'dempsri01',
#   26: 'dwyerji01',
#   27: 'flanami01',
#   28: 'fordda01',
#   29: 'grosswa01',
#   30: 'lacyle01',
#   31: 'lynnfr01',
#   32: 'martide01',
#   33: 'martiti01',
#   34: 'mcgresc01',
#   35: 'murraed02',
#   36: 'nolanjo01',
#   37: 'rayfofl01',
#   38: 'ripkeca01',
#   39: 'roeniga01',
#   40: 'sheetla01',
#   41: 'shelbjo01',
#   42: 'stewasa01',
#   43: 'youngmi01',
#   44: 'armasto01',
#   45: 'barrema02',
#   46: 'boggswa01',
#   47: 'bordiri01',
#   48: 'boydoi01',
#   49: 'bucknbi01',
#   50: 'clearma01',
#   51: 'clemero02',
#   52: 'crawfst01',
#   53: 'easlemi01',
#   54: 'evansdw01',
#   55: 'gedmari01',
#   56: 'gutieja01',
#   57: 'hoffmgl01',
#   58: 'hurstbr01',
#   59: 'juraked01',
#   60: 'kisonbr01',
#   61: 'milleri01',
#   62: 'nichore01',
#   63: 'nippeal01',
#   64: 'ojedabo01',
#   65: 'remyje01',
#   66: 'riceji01',
#   67: 'stanlbo01',
#   68: 'staplda01',
#   69: 'beniqju01',
#   70: 'boonebo01',
#   71: 'burleri01',
#   72: 'candejo01',
#   73: 'carewro01',
#   74: 'clibust02',
#   75: 'corbedo01',
#   76: 'decindo01',
#   77: 'downibr01',
#   78: 'forscke01',
#   79: 'grichbo01',
#   80: 'hendrge01',
#   81: 'hollaal01',
#   82: 'jacksre01',
#   83: 'jonesru01',
#   84: 'lacorfr01',
#   85: 'mccaski01',
#   86: 'mooredo01',
#   87: 'pettiga01',
#   88: 'romanro01',
#   89: 'sanchlu01',
#   90: 'schofdi02',
#   91: 'sconida01',
#   92: 'slatoji01',
#   93: 'suttodo01',
#   94: 'wilforo01',
#   95: 'wittmi01',
#   96: 'zahnge01',
#   97: 'agostju01',
#   98: 'baineha01',
#   99: 'bannifl01',
#   100: 'burnsbr01',
#   101: 'cruzju01',
#   102: 'dotsori01',
#   103: 'fiskca01',
#   104: 'fletcsc01',
#   105: 'guilloz01',
#   106: 'hairsje01',
#   107: 'hillma01',
#   108: 'jamesbo01',
#   109: 'kittlro01',
#   110: 'lawru01',
#   111: 'lollati01',
#   112: 'nelsoge01',
#   113: 'pacioto01',
#   114: 'salazlu01',
#   115: 'seaveto01',
#   116: 'spillda01',
#   117: 'walkegr01',
#   118: 'bosleth01',
#   119: 'brusswa01',
#   120: 'ceyro01',
#   121: 'davisjo02',
#   122: 'dernibo01',
#   123: 'durhale01',
#   124: 'eckerde01',
#   125: 'fontera01',
#   126: 'frazige01',
#   127: 'hebneri01',
#   128: 'lopesda01',
#   129: 'matthga01',
#   130: 'morelke01',
#   131: 'ruthvdi01',
#   132: 'sandbry01',
#   133: 'sandesc01',
#   134: 'smithle02',
#   135: 'sorenla01',
#   136: 'speiech01',
#   137: 'sutclri01',
#   138: 'troutst01',
#   139: 'woodsga01',
#   140: 'bellbu01',
#   141: 'brownto05',
#   142: 'conceda01',
#   143: 'foleyto02',
#   144: 'francjo01',
#   145: 'humeto01',
#   146: 'krencwa01',
#   147: 'mcgafan01',
#   148: 'milneed01',
#   149: 'oestero01',
#   150: 'parkeda01',
#   151: 'pastofr01',
#   152: 'perezto01',
#   153: 'powerte01',
#   154: 'pricejo02',
#   155: 'redusga01',
#   156: 'rosepe01',
#   157: 'sotoma01',
#   158: 'stupejo01',
#   159: 'tibbsja01',
#   160: 'vangoda01',
#   161: 'venabma01',
#   162: 'ayalabe01',
#   163: 'bandoch01',
#   164: 'bernato01',
#   165: 'blylebe01',
#   166: 'butlebr01',
#   167: 'camacer01',
#   168: 'cartejo01',
#   169: 'easteja01',
#   170: 'fischmi01',
#   171: 'francju01',
#   172: 'garlawa01',
#   173: 'hallme01',
#   174: 'hargrmi01',
#   175: 'heatone01',
#   176: 'jacobbr01',
#   177: 'ruhleve01',
#   178: 'tablepa01',
#   179: 'thornan01',
#   180: 'vukovge01',
#   181: 'waddeto01',
#   182: 'berenju01',
#   183: 'bergmda01',
#   184: 'brookto01',
#   185: 'castima02',
#   186: 'evansda01',
#   187: 'gibsoki01',
#   188: 'grubbjo01',
#   189: 'hernawi01',
#   190: 'herndla01',
#   191: 'lapoida01',
#   192: 'lemonch01',
#   193: 'lopezau01',
#   194: 'morrija02',
#   195: 'parrila02',
#   196: 'petryda01',
#   197: 'scherbi01',
#   198: 'terrewa01',
#   199: 'trammal01',
#   200: 'whitalo01',
#   201: 'wilcomi01',
#   202: 'ashbyal01',
#   203: 'basske01',
#   204: 'cabelen01',
#   205: 'cruzjo01',
#   206: 'davisgl01',
#   207: 'dawlebi01',
#   208: 'dipinfr01',
#   209: 'doranbi02',
#   210: 'garneph01',
#   211: 'kneppbo01',
#   212: 'morenom01',
#   213: 'niekrjo01',
#   214: 'puhlte01',
#   215: 'reynocr01',
#   216: 'ryanno01',
#   217: 'scottmi03',
#   218: 'smithda02',
#   219: 'spilmha01',
#   220: 'thondi01',
#   221: 'wallide01',
#   222: 'balbost01',
#   223: 'beckwjo01',
#   224: 'blackbu02',
#   225: 'brettge01',
#   226: 'conceon01',
#   227: 'gubicma01',
#   228: 'jacksda02',
#   229: 'jonesly01',
#   230: 'jonesmi02',
#   231: 'lampde01',
#   232: 'leibrch01',
#   233: 'leonade01',
#   234: 'mcraeha01',
#   235: 'motleda01',
#   236: 'ortajo01',
#   237: 'pryorgr01',
#   238: 'quiseda01',
#   239: 'saberbr01',
#   240: 'sheripa01',
#   241: 'sundbji01',
#   242: 'wathajo01',
#   243: 'wilsowi02',
#   244: 'bailobo01',
#   245: 'brockgr01',
#   246: 'diazca01',
#   247: 'duncama01',
#   248: 'goltzda01',
#   249: 'guerrpe01',
#   250: 'hershor01',
#   251: 'honeyri01',
#   252: 'johnsja01',
#   253: 'landrke01',
#   254: 'maldoca01',
#   255: 'marshmi02',
#   256: 'niedeto01',
#   257: 'oliveal01',
#   258: 'penaal01',
#   259: 'reussje01',
#   260: 'russebi01',
#   261: 'saxst01',
#   262: 'sciosmi01',
#   263: 'valenfe01',
#   264: 'welchbo01',
#   265: 'whitfte01',
#   266: 'yeagest01',
#   267: 'anderal02',
#   268: 'brunato01',
#   269: 'bushra01',
#   270: 'butchjo01',
#   271: 'castijo01',
#   272: 'davisro02',
#   273: 'engleda01',
#   274: 'filsope01',
#   275: 'gaettga01',
#   276: 'hatchmi01',
#   277: 'hrbekke01',
#   278: 'laudnti01',
#   279: 'puckeki01',
#   280: 'salasma01',
#   281: 'schroke01',
#   282: 'smallro02',
#   283: 'smithmi03',
#   284: 'teufeti01',
#   285: 'violafr01',
#   286: 'burrira01',
#   287: 'coopece01',
#   288: 'darwida01',
#   289: 'fingero01',
#   290: 'gantnji01',
#   291: 'haasmo01',
#   292: 'higuete01',
#   293: 'housepa02',
#   294: 'manniri01',
#   295: 'mcclubo01',
#   296: 'molitpa01',
#   297: 'moorech02',
#   298: 'oglivbe01',
#   299: 'romered01',
#   300: 'schrobi01',
#   301: 'simmote01',
#   302: 'vuckope01',
#   303: 'waitsri01',
#   304: 'yountro01',
#   305: 'brookhu01',
#   306: 'dawsoan01',
#   307: 'dilonmi01',
#   308: 'fishebr01',
#   309: 'flynndo01',
#   310: 'francte01',
#   311: 'gullibi01',
#   312: 'lawva01',
#   313: 'leach01',
#   314: 'lucasga01',
#   315: 'nicosst01',
#   316: 'palmeda01',
#   317: 'raineti01',
#   318: 'reardje01',
#   319: 'roberbe01',
#   320: 'schatda01',
#   321: 'smithbr01',
#   322: 'wallati01',
#   323: 'washiul01',
#   324: 'wohlfji01',
#   325: 'baylodo01',
#   326: 'berrada01',
#   327: 'bystrma01',
#   328: 'cowlejo01',
#   329: 'griffke01',
#   330: 'guidrro01',
#   331: 'hassero01',
#   332: 'henderi01',
#   333: 'kempst01',
#   334: 'mattido01',
#   335: 'meachbo01',
#   336: 'montejo01',
#   337: 'niekrph01',
#   338: 'randowi01',
#   339: 'righeda01',
#   340: 'samplbi01',
#   341: 'shirlbo01',
#   342: 'whitsed01',
#   343: 'winfida01',
#   344: 'wynegbu01',
#   345: 'backmwa01',
#   346: 'berenbr01',
#   347: 'bowala01',
#   348: 'cartega01',
#   349: 'darliro01',
#   350: 'fostege01',
#   351: 'gardero01',
#   352: 'goodedw01',
#   353: 'gormato03',
#   354: 'heepda01',
#   355: 'hernake01',
#   356: 'johnsho01',
#   357: 'knighra01',
#   358: 'lynched01',
#   359: 'mcdowro01',
#   360: 'oroscje01',
#   361: 'santara01',
#   362: 'siskdo01',
#   363: 'staubru01',
#   364: 'strawda01',
#   365: 'wilsomo01',
#   366: 'atherke01',
#   367: 'bakerdu01',
#   368: 'birtsti01',
#   369: 'bochtbr01',
#   370: 'codirch01',
#   371: 'collida02',
#   372: 'davismi02',
#   373: 'griffal01',
#   374: 'heathmi02',
#   375: 'hendest01',
#   376: 'howelja01',
#   377: 'johnto01',
#   378: 'kingmda01',
#   379: 'langfri01',
#   380: 'lansfca01',
#   381: 'mccatst01',
#   382: 'murphdw01',
#   383: 'norrimi01',
#   384: 'phillto02',
#   385: 'picciro01',
#   386: 'tellmto01',
#   387: 'aguaylu01',
#   388: 'anderla02',
#   389: 'carltst01',
#   390: 'corcoti01',
#   391: 'dennyjo01',
#   392: 'diazbo01',
#   393: 'grossgr01',
#   394: 'grosske01',
#   395: 'hayesvo01',
#   396: 'hudsoch02',
#   397: 'kniceal01',
#   398: 'koosmje01',
#   399: 'lefebjo01',
#   400: 'maddoga01',
#   401: 'rawlesh01',
#   402: 'ruckeda01',
#   403: 'samueju01',
#   404: 'schmimi01',
#   405: 'virgioz02',
#   406: 'almonbi01',
#   407: 'deleojo01',
#   408: 'guantce01',
#   409: 'hasslan01',
#   410: 'lezcasi01',
#   411: 'madlobi01',
#   412: 'mazzile01',
#   413: 'mcwilla01',
#   414: 'morriji01',
#   415: 'orsuljo01',
#   416: 'penato01',
#   417: 'rayjo01',
#   418: 'reuscri01',
#   419: 'rhoderi01',
#   420: 'robindo01',
# ...
#   943: 'rileser01',
#   944: 'schrobi01',
#   945: 'searara01',
#   946: 'sveumda01',
#   947: 'thomago01',
#   948: 'wegmabi01',
#   949: 'yountro01',
#   950: 'bilarda01',
#   951: 'brookhu01',
#   952: 'burketi01',
#   953: 'dawsoan01',
#   954: 'fitzgmi02',
#   955: 'flynndo01',
#   956: 'galaran01',
#   957: 'heskejo01',
#   958: 'huntra01',
#   959: 'johnswa03',
#   960: 'krencwa01',
#   961: 'lawva01',
#   962: 'leach01',
#   963: 'mcgafan01',
#   964: 'newmaal01',
#   965: 'nietoto01',
#   966: 'raineti01',
#   967: 'reardje01',
#   968: 'riverlu01',
#   969: 'roberbe01',
#   970: 'schatda01',
#   971: 'sebrabo01',
#   972: 'smithbr01',
#   973: 'thompja01',
#   974: 'thompsc01',
#   975: 'tibbsja01',
#   976: 'tomlida01',
#   977: 'wallati01',
#   978: 'webstmi01',
#   979: 'winnihe01',
#   980: 'wohlfji01',
#   981: 'youmafl01',
#   982: 'berrada01',
#   983: 'burnsbr01',
#   984: 'drabedo01',
#   985: 'easlemi01',
#   986: 'espinju01',
#   987: 'fischmi01',
#   988: 'fishebr01',
#   989: 'griffke01',
#   990: 'guidrro01',
#   991: 'hassero01',
#   992: 'henderi01',
#   993: 'johnto01',
#   994: 'kempst01',
#   995: 'mattido01',
#   996: 'montejo01',
#   997: 'morenom01',
#   998: 'niekrjo01',
#   999: 'paglimi01',
#   ...},
#  'salary': {0: 870000,
#   1: 550000,
#   2: 545000,
#   3: 633333,
#   4: 625000,
#   5: 800000,
#   6: 150000,
#   7: 483333,
#   8: 772000,
#   9: 250000,
#   10: 1500000,
#   11: 455000,
#   12: 407500,
#   13: 275000,
#   14: 775000,
#   15: 1625000,
#   16: 616667,
#   17: 450000,
#   18: 120000,
#   19: 750000,
#   20: 1354167,
#   21: 800000,
#   22: 625000,
#   23: 480000,
#   24: 437500,
#   25: 512500,
#   26: 375000,
#   27: 641667,
#   28: 450000,
#   29: 483333,
#   30: 725000,
#   31: 1090000,
#   32: 560000,
#   33: 440000,
#   34: 547143,
#   35: 1472819,
#   36: 341667,
#   37: 128500,
#   38: 800000,
#   39: 558333,
#   40: 60000,
#   41: 130000,
#   42: 581250,
#   43: 121000,
#   44: 915000,
#   45: 272500,
#   46: 1000000,
#   47: 115000,
#   48: 177500,
#   49: 747500,
#   50: 580000,
#   51: 140000,
#   52: 160000,
#   53: 650000,
#   54: 800000,
#   55: 477500,
#   56: 130000,
#   57: 335000,
#   58: 300000,
#   59: 125000,
#   60: 370000,
#   61: 275000,
#   62: 260000,
#   63: 165000,
#   64: 240000,
#   65: 483333,
#   66: 779227,
#   67: 1075000,
#   68: 325000,
#   69: 365000,
#   70: 883000,
#   71: 856667,
#   72: 612500,
#   73: 875000,
#   74: 60000,
#   75: 360000,
#   76: 1100000,
#   77: 808333,
#   78: 633333,
#   79: 700000,
#   80: 737000,
#   81: 625000,
#   82: 1058894,
#   83: 390000,
#   84: 346667,
#   85: 60000,
#   86: 407500,
#   87: 125000,
#   88: 146500,
#   89: 340000,
#   90: 120000,
#   91: 130000,
#   92: 437500,
#   93: 750000,
#   94: 266667,
#   95: 683333,
#   96: 550000,
#   97: 147500,
#   98: 675000,
#   99: 811250,
#   100: 727500,
#   101: 1242333,
#   102: 900000,
#   103: 685000,
#   104: 165000,
#   105: 60000,
#   106: 150000,
#   107: 200000,
#   108: 265000,
#   109: 300000,
#   110: 565000,
#   111: 463000,
#   112: 110000,
#   113: 333333,
#   114: 325000,
#   115: 1136262,
#   116: 390000,
#   117: 195000,
#   118: 215000,
#   119: 375000,
#   120: 1450000,
#   121: 550000,
#   122: 406250,
#   123: 800000,
#   124: 750000,
#   125: 200000,
#   126: 483333,
#   127: 310000,
#   128: 490000,
#   129: 600000,
#   130: 865000,
#   131: 766667,
#   132: 505000,
#   133: 500000,
#   134: 670000,
#   135: 320000,
#   136: 225000,
#   137: 1260000,
#   138: 640000,
#   139: 321667,
#   140: 751297,
#   141: 60000,
#   142: 920000,
#   143: 117500,
#   144: 75000,
#   145: 833333,
#   146: 250000,
#   147: 110000,
#   148: 300000,
#   149: 550000,
#   150: 970000,
#   151: 350000,
#   152: 225000,
#   153: 255000,
#   154: 410000,
#   155: 227500,
#   156: 358858,
#   157: 1071429,
#   158: 250000,
#   159: 60000,
#   160: 60000,
#   161: 155000,
#   162: 303333,
#   163: 225000,
#   164: 400000,
#   165: 650000,
#   166: 425000,
#   167: 115000,
#   168: 110000,
#   169: 265000,
#   170: 190000,
#   171: 455000,
#   172: 200000,
#   173: 210000,
#   174: 458333,
#   175: 225000,
#   176: 140000,
#   177: 295000,
#   178: 285000,
#   179: 1100000,
#   180: 375000,
#   181: 125000,
#   182: 240000,
#   183: 262500,
#   184: 250000,
#   185: 76000,
#   186: 1083333,
#   187: 685000,
#   188: 250000,
#   189: 660000,
#   190: 675000,
#   191: 380000,
#   192: 670000,
#   193: 575000,
#   194: 885000,
#   195: 766667,
#   196: 875000,
#   197: 100000,
#   198: 177500,
#   199: 517143,
#   200: 670000,
#   201: 550000,
#   202: 416667,
#   203: 155000,
#   204: 291667,
#   205: 796383,
#   206: 60000,
#   207: 295000,
#   208: 255000,
#   209: 325000,
#   210: 745000,
#   211: 850000,
#   212: 700000,
#   213: 825000,
#   214: 541667,
#   215: 350000,
#   216: 1350000,
#   217: 360000,
#   218: 500000,
#   219: 160000,
#   220: 675000,
#   221: 341667,
#   222: 205000,
#   223: 358000,
#   224: 465000,
#   225: 1000000,
#   226: 250000,
#   227: 115000,
#   228: 95000,
#   229: 202500,
#   230: 100000,
#   231: 535000,
#   232: 225000,
#   233: 871429,
#   234: 800000,
#   235: 155500,
#   236: 450000,
#   237: 316667,
#   238: 975000,
#   239: 150000,
#   240: 175000,
#   241: 608333,
#   242: 425000,
#   243: 843750,
#   244: 330000,
#   245: 150000,
#   246: 120000,
#   247: 60000,
#   248: 500000,
#   249: 1270000,
#   250: 212000,
#   251: 705000,
#   252: 150000,
#   253: 537500,
#   254: 140000,
#   255: 333000,
#   256: 370000,
#   257: 750000,
#   258: 350000,
#   259: 980000,
#   260: 450000,
#   261: 465000,
#   262: 435000,
#   263: 1200000,
#   264: 643750,
#   265: 316667,
#   266: 500000,
#   267: 62500,
#   268: 425000,
#   269: 120000,
#   270: 320000,
#   271: 550000,
#   272: 650000,
#   273: 215000,
#   274: 120000,
#   275: 415000,
#   276: 293750,
#   277: 560000,
#   278: 145000,
#   279: 130000,
#   280: 60000,
#   281: 150000,
#   282: 728571,
#   283: 335000,
#   284: 110000,
#   285: 375000,
#   286: 581250,
#   287: 1176190,
#   288: 565000,
#   289: 1065000,
#   290: 687500,
#   291: 679167,
#   292: 60000,
#   293: 215000,
#   294: 510000,
#   295: 480000,
#   296: 950000,
#   297: 365000,
#   298: 560000,
#   299: 290000,
#   300: 100000,
#   301: 1000000,
#   302: 540000,
#   303: 460000,
#   304: 1000000,
#   305: 550000,
#   306: 1033333,
#   307: 175000,
#   308: 60000,
#   309: 350000,
#   310: 250000,
#   311: 700000,
#   312: 375000,
#   313: 650000,
#   314: 513500,
#   315: 105000,
#   316: 375000,
#   317: 1200000,
#   318: 850000,
#   319: 95000,
#   320: 375000,
#   321: 290000,
#   322: 565000,
#   323: 650000,
#   324: 308333,
#   325: 810000,
#   326: 477500,
#   327: 250000,
#   328: 120000,
#   329: 1075000,
#   330: 900000,
#   331: 425000,
#   332: 1470000,
#   333: 1420000,
#   334: 455000,
#   335: 100000,
#   336: 637500,
#   337: 600000,
#   338: 600000,
#   339: 680000,
#   340: 435000,
#   341: 637500,
#   342: 800000,
#   343: 1795704,
#   344: 550000,
#   345: 200000,
#   346: 325000,
#   347: 525000,
#   348: 2028571,
#   349: 230000,
#   350: 1942857,
#   351: 100000,
#   352: 450000,
#   353: 150000,
#   354: 260000,
#   355: 1100000,
#   356: 115000,
#   357: 560000,
#   358: 330000,
#   359: 60000,
#   360: 650000,
#   361: 125000,
#   362: 275000,
#   363: 300000,
#   364: 516667,
#   365: 591667,
#   366: 107333,
#   367: 575000,
#   368: 60000,
#   369: 350000,
#   370: 141500,
#   371: 700000,
#   372: 305000,
#   373: 610000,
#   374: 425000,
#   375: 150000,
#   376: 262500,
#   377: 600000,
#   378: 1087500,
#   379: 608333,
#   380: 900000,
#   381: 520000,
#   382: 845833,
#   383: 283107,
#   384: 220000,
#   385: 100000,
#   386: 207500,
#   387: 237000,
#   388: 250500,
#   389: 1075000,
#   390: 220000,
#   391: 1109333,
#   392: 620000,
#   393: 350000,
#   394: 140000,
#   395: 500000,
#   396: 192500,
#   397: 60000,
#   398: 600000,
#   399: 310000,
#   400: 820333,
#   401: 700000,
#   402: 220000,
#   403: 240000,
#   404: 2130300,
#   405: 350000,
#   406: 255000,
#   407: 155000,
#   408: 150000,
#   409: 129166,
#   410: 425000,
#   411: 975500,
#   412: 600000,
#   413: 796667,
#   414: 232500,
#   415: 60000,
#   416: 1075000,
#   417: 632000,
#   418: 200000,
#   419: 645000,
#   420: 520000,
#   421: 350000,
#   422: 830000,
#   423: 1066667,
#   424: 130000,
#   425: 140000,
#   426: 150000,
#   427: 160000,
#   428: 240000,
#   429: 175000,
#   430: 975000,
#   431: 1713333,
#   432: 440000,
#   433: 200000,
#   434: 975000,
#   435: 340000,
#   436: 870000,
#   437: 270000,
#   438: 140000,
#   439: 150000,
#   440: 900000,
#   441: 325000,
#   442: 537500,
#   443: 556250,
#   444: 1137000,
#   445: 130000,
#   446: 512500,
#   447: 470000,
#   448: 437500,
#   449: 125000,
#   450: 400000,
#   451: 225000,
#   452: 310000,
#   453: 183000,
#   454: 160000,
#   455: 228000,
#   456: 97000,
#   457: 114400,
#   458: 175000,
#   459: 180000,
#   460: 71600,
#   461: 690000,
#   462: 315000,
#   463: 159000,
#   464: 272500,
#   465: 250000,
#   466: 385000,
#   467: 60000,
#   468: 550000,
#   469: 195000,
#   470: 767500,
#   471: 85000,
#   472: 135000,
#   473: 170000,
#   474: 275000,
#   475: 355000,
#   476: 630000,
#   477: 355000,
#   478: 500000,
#   479: 900000,
#   480: 865000,
#   481: 197000,
#   482: 462500,
#   483: 709714,
#   484: 375000,
#   485: 750000,
#   486: 1030000,
#   487: 160000,
#   488: 457500,
#   489: 562500,
#   490: 1555000,
#   491: 60000,
#   492: 110000,
#   493: 150000,
#   494: 700000,
#   495: 583333,
#   496: 135000,
#   497: 560000,
#   498: 110000,
#   499: 200000,
#   500: 100000,
#   501: 250000,
#   502: 208750,
#   503: 475000,
#   504: 112500,
#   505: 740000,
#   506: 740000,
#   507: 1440000,
#   508: 457500,
#   509: 170000,
#   510: 350000,
#   511: 650000,
#   512: 565000,
#   513: 636667,
#   514: 683333,
#   515: 117500,
#   516: 60000,
#   517: 235000,
#   518: 165000,
#   519: 560000,
#   520: 310000,
#   521: 344000,
#   522: 215000,
#   523: 250000,
#   524: 505000,
#   525: 590000,
#   526: 135000,
#   527: 185000,
#   528: 720000,
#   529: 400000,
#   530: 170000,
#   531: 875000,
#   532: 325000,
#   533: 335000,
#   534: 350000,
#   535: 833333,
#   536: 580000,
#   537: 127500,
#   538: 740000,
#   539: 60000,
#   540: 256667,
#   541: 131250,
#   542: 475000,
#   543: 356300,
#   544: 185000,
#   545: 587500,
#   546: 325000,
#   547: 1000000,
#   548: 730000,
#   549: 370000,
#   550: 367500,
#   551: 60000,
#   552: 880000,
#   553: 565000,
#   554: 600000,
#   555: 769452,
#   556: 200000,
#   557: 786667,
#   558: 425000,
#   559: 1800000,
#   560: 505000,
#   561: 105000,
#   562: 687500,
#   563: 225000,
#   564: 100000,
#   565: 257500,
#   566: 1825000,
#   567: 825000,
#   568: 60000,
#   569: 390000,
#   570: 825000,
#   571: 470000,
#   572: 1000000,
#   573: 200000,
#   574: 60000,
#   575: 1729167,
#   576: 60000,
#   577: 575000,
#   578: 750000,
#   579: 600000,
#   580: 450000,
#   581: 837500,
#   582: 120000,
#   583: 250000,
#   584: 510000,
#   585: 442066,
#   586: 140000,
#   587: 400000,
#   588: 639791,
#   589: 350000,
#   590: 450000,
#   591: 167500,
#   592: 115000,
#   593: 107500,
#   594: 725000,
#   595: 1190000,
#   596: 560458,
#   597: 487078,
#   598: 911051,
#   599: 925814,
#   600: 285000,
#   601: 310000,
#   602: 1150000,
#   603: 120000,
#   604: 240000,
#   605: 70000,
#   606: 60000,
#   607: 387500,
#   608: 1000000,
#   609: 435000,
#   610: 660696,
#   611: 1350000,
#   612: 375000,
#   613: 80000,
#   614: 785000,
#   615: 340000,
#   616: 330000,
#   617: 1017757,
#   618: 70000,
#   619: 650000,
#   620: 60000,
#   621: 412000,
#   622: 350000,
#   623: 495000,
#   624: 541250,
#   625: 265000,
#   626: 255000,
#   627: 60000,
#   628: 1984423,
#   629: 375000,
#   630: 500000,
#   631: 75000,
#   632: 1060000,
#   633: 300000,
#   634: 381113,
#   635: 110000,
#   636: 85000,
#   637: 853479,
#   638: 856667,
#   639: 800000,
#   640: 410000,
#   641: 1200000,
#   642: 808333,
#   643: 60000,
#   644: 100000,
#   645: 170000,
#   646: 500000,
#   647: 939333,
#   648: 82500,
#   649: 1102946,
#   650: 440000,
#   651: 560000,
#   652: 65000,
#   653: 500000,
#   654: 142000,
#   655: 1000000,
#   656: 142000,
#   657: 300000,
#   658: 425000,
#   659: 60000,
#   660: 210000,
#   661: 400000,
#   662: 890000,
#   663: 60000,
#   664: 416667,
#   665: 933333,
#   666: 900000,
#   667: 775000,
#   668: 930000,
#   669: 115000,
#   670: 68000,
#   671: 66500,
#   672: 60000,
#   673: 60000,
#   674: 295000,
#   675: 600000,
#   676: 975000,
#   677: 875000,
#   678: 60000,
#   679: 80000,
#   680: 150000,
#   681: 156667,
#   682: 200000,
#   683: 195000,
#   684: 555000,
#   685: 60000,
#   686: 400000,
#   687: 60000,
#   688: 60000,
#   689: 240000,
#   690: 150000,
#   691: 465000,
#   692: 1132652,
#   693: 75000,
#   694: 200000,
#   695: 60000,
#   696: 400000,
#   697: 327500,
#   698: 575000,
#   699: 1400000,
#   700: 833333,
#   701: 558333,
#   702: 100000,
#   703: 983333,
#   704: 783333,
#   705: 240000,
#   706: 250000,
#   707: 633333,
#   708: 64000,
#   709: 100000,
#   710: 100000,
#   711: 60000,
#   712: 490000,
#   713: 60000,
#   714: 850000,
#   715: 760000,
#   716: 60000,
#   717: 850000,
#   718: 1050000,
#   719: 325000,
#   720: 665000,
#   721: 800000,
#   722: 720000,
#   723: 275000,
#   724: 1530000,
#   725: 550000,
#   726: 890000,
#   727: 325000,
#   728: 870000,
#   729: 215000,
#   730: 102500,
#   731: 920000,
#   732: 60000,
#   733: 90000,
#   734: 1083333,
#   735: 775000,
#   736: 272500,
#   737: 195000,
#   738: 545555,
#   739: 60000,
#   740: 60000,
#   741: 60000,
#   742: 350000,
#   743: 60000,
#   744: 650000,
#   745: 1100000,
#   746: 405000,
#   747: 275000,
#   748: 500000,
#   749: 430000,
#   750: 92500,
#   751: 1000000,
#   752: 1150000,
#   753: 60000,
#   754: 150000,
#   755: 225000,
#   756: 80000,
#   757: 70000,
#   758: 60000,
#   759: 60000,
#   760: 225000,
#   761: 580000,
#   762: 850000,
#   763: 145000,
#   764: 80000,
#   765: 190000,
#   766: 177500,
#   767: 350000,
#   768: 575000,
#   769: 215000,
#   770: 350000,
#   771: 310000,
#   772: 437500,
#   773: 90000,
#   774: 60000,
#   775: 300000,
#   776: 97500,
#   777: 110000,
#   778: 65000,
#   779: 60000,
#   780: 275000,
#   781: 110000,
#   782: 60000,
#   783: 60000,
#   784: 395000,
#   785: 1100000,
#   786: 270000,
#   787: 92000,
#   788: 60000,
#   789: 316667,
#   790: 325000,
#   791: 200000,
#   792: 75000,
#   793: 700000,
#   794: 793333,
#   795: 1200000,
#   796: 250000,
#   797: 960000,
#   798: 687500,
#   799: 60000,
#   800: 72500,
#   801: 550000,
#   802: 698571,
#   803: 62500,
#   804: 875000,
#   805: 80000,
#   806: 850000,
#   807: 875000,
#   808: 150000,
#   809: 60000,
#   810: 60000,
#   811: 662500,
#   812: 260000,
#   813: 275000,
#   814: 567143,
#   815: 670000,
#   816: 60000,
#   817: 525000,
#   818: 310000,
#   819: 95000,
#   820: 755000,
#   821: 120000,
#   822: 325000,
#   823: 65000,
#   824: 280000,
#   825: 550000,
#   826: 600000,
#   827: 80000,
#   828: 65000,
#   829: 1000000,
#   830: 223275,
#   831: 60000,
#   832: 85000,
#   833: 850000,
#   834: 416667,
#   835: 1125000,
#   836: 666667,
#   837: 650000,
#   838: 600000,
#   839: 366667,
#   840: 525000,
#   841: 60000,
#   842: 165000,
#   843: 645000,
#   844: 1471429,
#   845: 60000,
#   846: 85000,
#   847: 250000,
#   848: 67000,
#   849: 100000,
#   850: 175000,
#   851: 185000,
#   852: 60000,
#   853: 360000,
#   854: 770000,
#   855: 883333,
#   856: 650000,
#   857: 450000,
#   858: 293808,
#   859: 150000,
#   860: 925000,
#   861: 925000,
#   862: 75000,
#   863: 1000000,
#   864: 653128,
#   865: 400000,
#   866: 485000,
#   867: 1175000,
#   868: 200000,
#   869: 375000,
#   870: 200000,
#   871: 325000,
#   872: 450000,
#   873: 200000,
#   874: 150000,
#   875: 65000,
#   876: 1370000,
#   877: 60000,
#   878: 1000000,
#   879: 60000,
#   880: 755000,
#   881: 175000,
#   882: 637500,
#   883: 841667,
#   884: 650000,
#   885: 220000,
#   886: 531250,
#   887: 350000,
#   888: 62000,
#   889: 1000000,
#   890: 450000,
#   891: 584624,
#   892: 800000,
#   893: 65000,
#   894: 409485,
#   895: 1600000,
#   896: 455000,
#   897: 68500,
#   898: 743750,
#   899: 60000,
#   900: 65000,
#   901: 1450000,
#   902: 740000,
#   903: 220000,
#   904: 385000,
#   905: 725000,
#   906: 60000,
#   907: 515000,
#   908: 100000,
#   909: 666667,
#   910: 1060000,
#   911: 115000,
#   912: 155000,
#   913: 75000,
#   914: 60000,
#   915: 62500,
#   916: 255000,
#   917: 60000,
#   918: 115000,
#   919: 740000,
#   920: 450000,
#   921: 674000,
#   922: 60000,
#   923: 60000,
#   924: 60000,
#   925: 675000,
#   926: 671560,
#   927: 60000,
#   928: 607322,
#   929: 610000,
#   930: 95000,
#   931: 887500,
#   932: 779167,
#   933: 195000,
#   934: 60000,
#   935: 90000,
#   936: 495000,
#   937: 487500,
#   938: 1160000,
#   939: 402500,
#   940: 70000,
#   941: 766593,
#   942: 60000,
#   943: 175000,
#   944: 155000,
#   945: 121500,
#   946: 60000,
#   947: 60000,
#   948: 70000,
#   949: 950000,
#   950: 80000,
#   951: 650000,
#   952: 160000,
#   953: 1047000,
#   954: 147000,
#   955: 325000,
#   956: 67500,
#   957: 170000,
#   958: 65000,
#   959: 65000,
#   960: 320000,
#   961: 450000,
#   962: 850000,
#   963: 180000,
#   964: 62500,
#   965: 90000,
#   966: 1515000,
#   967: 850000,
#   968: 60000,
#   969: 138100,
#   970: 415000,
#   971: 61500,
#   972: 700000,
#   973: 1000000,
#   974: 170000,
#   975: 127500,
#   976: 60000,
#   977: 650000,
#   978: 120000,
#   979: 87500,
#   980: 350000,
#   981: 70000,
#   982: 557500,
#   983: 750000,
#   984: 60000,
#   985: 658333,
#   986: 65000,
#   987: 200000,
#   988: 120000,
#   989: 1050000,
#   990: 975000,
#   991: 400873,
#   992: 1570000,
#   993: 60000,
#   994: 1220000,
#   995: 1375000,
#   996: 716667,
#   997: 500000,
#   998: 750000,
#   999: 120000,
#   ...}}

# %% [markdown]
# #### Create Dataframe Using the Constructor

# %% [markdown]
# Read the documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html#pandas.DataFrame and create a dataframe using pd.DataFrame from the dictionary created in the iterrows() exercise. Change the header to "a", "b", "c", ... at creation time.

# %%
df = pd.DataFrame(data=d).set_axis(['a', 'b','c','d','e'], axis=1)


df
# Out:
#           a    b   c          d         e
# 0      1985  ATL  NL  barkele01    870000
# 1      1985  ATL  NL  bedrost01    550000
# 2      1985  ATL  NL  benedbr01    545000
# 3      1985  ATL  NL   campri01    633333
# 4      1985  ATL  NL  ceronri01    625000
# ...     ...  ...  ..        ...       ...
# 25570  2015  WAS  NL  treinbl01    512800
# 25571  2015  WAS  NL  ugglada01    507500
# 25572  2015  WAS  NL  werthja01  21000000
# 25573  2015  WAS  NL  zimmejo02  16500000
# 25574  2015  WAS  NL  zimmery01  14000000
#
# [25575 rows x 5 columns]

# %% [markdown]
# ### Numpy

# %% [markdown]
# Quick start: https://www.numpy.org/devdocs/user/quickstart.html
#
# Numpy axes explaination: https://www.sharpsightlabs.com/blog/numpy-axes-explained/

# %% [markdown]
# #### The np.array Method

# %% [markdown]
# Example 1:
#
# ```python
# ls = [1, 2, 3]
# arr = np.array(ls)
# ```
#
# Example 2:
# ```python
# >>> np.array([[1, 2], [3, 4]])
# array([[1, 2],
#        [3, 4]])
# ```

# %% [markdown]
# Now, create a 2-dimensional Python list object, then convert it to a Numpy array object.

# %%
ls = [[1,3],[2,4]]

arr = np.array(ls)
print(arr)
print(type(arr))
# Out:
# [[1 3]
#  [2 4]]
# <class 'numpy.ndarray'>

# %% [markdown]
# #### ndarray Objects' Attributes

# %% [markdown]
# Play with the **ndim, shape, size, dtype, itemsize and data** attribute.
#
# Example:
#
# ```python
# >>> arr = np.array([[1, 2], [3, 4]])
# >>> arr.ndim
# 2
# ```

# %%
arr.shape
# Out:
# (2, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.size
# Out:
# 4

# %%
arr.itemsize
# Out:
# 8

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.data

# %% [markdown]
# #### Dimension of ndarray Ojects

# %% [markdown]
# Play with the reshape() and flatten() method.
#
# Example:
# ```python
# >>> arr = np.array([[1, 2], [3, 4]])
# >>> arr.flatten()
# array([1, 2, 3, 4])
# ```

# %%
arr.flatten()
# Out:
# array([1, 3, 2, 4])

# %%
a = np.arange(6).reshape((3, 2))
print(a)
# Out:
# [[0 1]
#  [2 3]
#  [4 5]]

# %%
arr.reshape(1,4)
# Out:
# array([[1, 3, 2, 4]])

# %% [markdown]
# #### The Slice Operation of ndarray Objects

# %% [markdown]
# Understand how the slice operation works for 1-D array and 2-D array.
#
# Example:
#
# ```python
# >>> arr = np.array([[1, 2, 3], [3, 4, 6], [7, 8, 9]])
# >>> arr[1:]
# array([[3, 4, 6],
#        [7, 8, 9]])
# >>> arr[1:, 0:2]
# array([[3, 4],
#        [7, 8]])
# ```

# %%
arr[0:][0:2]
# Out:
# array([[1, 3],
#        [2, 4]])

# %% [markdown]
# #### The Calculation of ndarray Objects

# %% [markdown]
# Play with the **argmin(), argmax(), min(), max(), mean(), sum(), std(), dot(), square(), sqrt(), abs(). exp(), sign(), mod()** method.
#
# Example:
#
# ```python
# >>> np.square(array)
# array([[ 1,  4,  9],
#        [ 9, 16, 36],
#        [49, 64, 81]])
#
# ```

# %%
a = np.array([[ 1,  4,  9],
       [ 9, 16, 36],
       [49, 64, 81]])
b= np.array([[ 1,  4,  9],
       [ 9, 16, 36],
       [49, 64, 81]])
a.dot(b)
# Out:
# array([[ 478,  644,  882],
#        [1917, 2596, 3573],
#        [4594, 6404, 9306]])

# %% [markdown]
# #### Other Important Methods Inside Module Numpy

# %% [markdown]
# Play with the arange(), ones(), zeros(), eye(), linspace(), concatenate() method.
#
# Example:
#
# ```python
# >>> np.eye(3)
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
# ```

# %%
np.ones(4)
# Out:
# array([1., 1., 1., 1.])

# %% [markdown]
# ### Scikit-Learn

# %% [markdown]
# The followings are packages (or methods) in Python (Scikit-Learn and Scipy) that will be frequently used in your programming assignment. So, please read carefully.
#
# - Data Preprocessing (https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing)
#     - Standardization: StandardScaler
#     - Normalization: MinMaxScaler
#     - Quantifing Categorical Features: LabelEncoder. OneHotEncoder
#     - Construct Train and Test Set: model_selection.train_test_split
# - KNN: KNeighborsClassifier
# - Linear Regression: LinearRegression
# - Logistic Regression: LogisticRegression, LogisticRegressionCV
# - Feature Selection / Model Selection
#     - L1 Penalized Regression (Lasso Regression) with Cross-Validation: LassoCV
#     - L2 Penalized Regression (Ridge Regression) with Cross-Validation: RidgeCV
#     - Cross-Validation: StratifiedKFold, RepeatedKFold, LeaveOneOut, KFold, model_selection.cross_validate, model_selection.cross_val_predict, model_selection.cross_val_score
#     - Model Metrics (https://scikit-learn.org/stable/modules/classes.html#sklearn-metrics-metrics): accuracy_score, auc, f1_score, hamming_loss, precision_score, recall_score, roc_auc_score
# - Decision Tree: DecisionTreeClassifier, DecisionTreeRegressor
# - Bootstrap, Ensemble Methods
#     - Bootstrap: bootstrapped (https://pypi.org/project/bootstrapped/)
#     - Bagging: RandomForestClassifier, RandomForestRegressor
#     - Boosting: AdaBoostClassifier, AdaBoostRegressor
# - Support Vector Machines (https://scikit-learn.org/stable/modules/svm.html#svm): LinearSVC, LinearSVR
# - Multiclass and Multilabel Classification (https://scikit-learn.org/stable/modules/classes.html#module-sklearn.multiclass)
#     - One-vs-one Multiclass Strategy: OneVsOneClassifier
#     - One-vs-the-rest (OvR) multiclass/multilabel strategy / OneVsRestClassifier
# - Unsupervised Learning
#     - K-means Clustering: KMeans
#     - Hierarchical Clustering: scipy.cluster.hierarchy (not scikit-learn)
# - Semisupervised Learning (https://scikit-learn.org/stable/modules/label_propagation.html)

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# **Quick start:** https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html
#
# **Exercises:**

# %% [markdown]
# (a) Create two one dimensional arrays x and y and plot y vs x, add title, xlabel, ylabel, grid.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y = np.array([j ** 2 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting the parabola.

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-5, 5, num=20)
y = np.array([j ** 2 for j in x])

plt.plot(x,y)

plt.show()

# %% [markdown]
# What happens if the independent variable is not sorted before plotting? Try plotting directly using the following defined array.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# np.random.shuffle(x)
# y = np.array([j ** 2 for j in x])
# ```

# %%
np.random.shuffle(x)
plt.plot(x,y)

plt.show()

# %% [markdown]
# (b) Create multiple arrays and plot them with different styles, add legends, add text/mathematical equations on the plot.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y1 = np.array([j for j in x])
# y2 = np.array([j ** 2 for j in x])
# y3 = np.array([j ** 3 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting curve $\left(x, y1\right)$, $\left(x, y2\right)$ and $\left(x, y3\right)$.

# %%
x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 3 for j in x])


plt.title(r'$\sigma_i=15$ rrr')
plt.ylabel('y')
plt.plot(x,y1,'bs',x,y2,'r--',x,y3, 'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f5dc8b62b30>,
#  <matplotlib.lines.Line2D at 0x7f5dc8b62b00>,
#  <matplotlib.lines.Line2D at 0x7f5dc8b62d40>]

# %% [markdown]
# (c) Create multiple arrays and plot them into one figure **(No multiple figure and no subplot is allowed in this question)**.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y1 = np.array([j for j in x])
# y2 = np.array([j ** 2 for j in x])
# y3 = np.array([j ** 3 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting curve $\left(x, y1\right)$, $\left(x, y2\right)$ and $\left(x, y3\right)$.

# %% [markdown]
# (d) Create multiple subplots, play around with the figure size, figure title, and its font style and font size **(One curve is plotted in one subplot in this question)**.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y1 = np.array([j for j in x])
# y2 = np.array([j ** 2 for j in x])
# y3 = np.array([j ** 3 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting curve $\left(x, y1\right)$, $\left(x, y2\right)$ and $\left(x, y3\right)$.

# %%
fig, axs = plt.subplots(2,2)

axs[0,1].plot(x, y1,'tab:green')
axs[1,0].plot(x, y2)
axs[0, 1].set_title('Axis [0, 1]')
# Out:
# Text(0.5, 1.0, 'Axis [0, 1]')

# %% [markdown]
# (e) Change the limits on x and y axes, **use logarithmic axes to plot**.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y = np.array([j ** 2 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting the parabola.

# %%
plt.plot(x, y1)
plt.yscale('log')
plt.title('log')
plt.yscale('log')

# %% [markdown]
# ### Pandas's DataFrame.plot and Seaborn

# %% [markdown]
# #### Pandas's DataFrame.plot
#
# Use the Salaries.csv again (You can use the dataframe object loaded from section 3.1).

# %% [markdown]
# (a) For team 'ATL', plot a scatter plot between feature yearID and salary.

# %%
salary = pd.read_csv(r'Salaries.csv') 
filter_salary = salary[salary['teamID'] == 'ATL']
x = filter_salary['yearID'].to_list()
y = filter_salary['salary'].to_list()

plt.scatter(x,y)

# %%
salary = pd.read_csv(r'Salaries.csv') 

filter_salary = salary[salary['teamID'] == 'ATL']

plt.scatter(filter_salary['yearID'],filter_salary['salary'])

# %% [markdown]
# (b) For year 1985, plot a bar chart to show the average salary for each team.

# %%
fil_year = salary[salary['yearID'] == 1985]

b = fil_year.groupby('teamID')['salary'].mean()
#s = b.to_list()
plt.bar(b.index,b.values)
# Out:
# <BarContainer object of 26 artists>

# %% [markdown]
# (c) For team 'ATL', plot a line chart to show how the annual average salary change by years.

# %%
fil_team = salary[salary['teamID'] == 'ATL']

b = fil_team.groupby('yearID')['salary'].sum()

plt.plot(b.index,b.values)

# %% [markdown]
# #### Seaborn

# %% [markdown]
# (a) Append one more numeric feature to the data frame (can be generated randomly), then for team 'ATL', use the seaborn.pairplot to plot scatter plots among all numeric features in the data frame for team.

# %%
import seaborn as sns


salary.loc[25575] = [1988, 'ATL', 'NL','defheuw01',890000] 
fil_atl = salary[salary['teamID'] == 'ATL']
sns.pairplot(fil_atl)

# %% [markdown]
# (b) For year 1985 and for each team, plot a boxplot to show how the salary distribute within a team.

# %%
fil_yr = salary[salary['yearID'] == 1985]

b = fil_yr.groupby('teamID')['salary'].mean()
sns.barplot(x = b.index, y = b.values)
# Out:
# <AxesSubplot:xlabel='teamID'>

# %% [markdown]
# (c) Read the offical documentation (https://seaborn.pydata.org/) to understand how lmplot, catplot, relplot, and jointplot works.

# %% [markdown]
# ### Jupyter Notebook

# %% [markdown]
# #### Jupyter Notebook Extensions

# %% [markdown]
# Extensions such as the code formatter, table of content is to make your development more efficient. To explore it, please refer to https://github.com/ipython-contrib/jupyter_contrib_nbextensions.

# %% [markdown]
# #### Jupyter Visual Debugger

# %% [markdown]
# The Pixie Debugger is a visual debugger for debugging on Jupyter Notebook. To explore it, please refer to https://medium.com/codait/the-visual-python-debugger-for-jupyter-notebooks-youve-always-wanted-761713babc62.

# %% [markdown]
# ### Git and GitHub

# %% [markdown]
# 1. In the directory that where this jupyter notebook file locates in, init a Git repository.
# 2. Checkout a new branch called dev and commit the current notebook within this branch.
# 3. Merge the dev branch to the master branch (the default branch).
# 4. Create a temporary repository (just for practicing and you can delete it later) in GitHub.
# 5. Push new changes in the master branch to the remote repository created in step 4.
# 6. Checkout the dev branch again and do some changes to your notebook, and then repeat step 3 and step 5.
